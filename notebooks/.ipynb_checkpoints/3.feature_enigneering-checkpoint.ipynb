# %% [markdown]
# # Binning
# - 使用多输出决策树的最优分布分箱

# %%
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/curated/combined_data_div.csv')

# %%
data.columns
# Out:
# Index(['PtAge', 'WBC', 'RBC', 'HGB', 'HCT', 'MCV', 'MCH', 'MCHC', 'PLT',
#        'RDW-SD',
#        ...
#        'HFLC1_div_HFLC2', 'HFLC1_div_NRBC#', 'HFLC1_div_NRBC%',
#        'HFLC2_div_NRBC#', 'HFLC2_div_NRBC%', 'NRBC#_div_NRBC%', 'FYZ-IgM',
#        '甲流', 'Diagnosis', 'diagnosis_tokenized'],
#       dtype='object', length=532)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.multioutput import MultiOutputClassifier

def optimal_binning_boundary(x: pd.Series, y: pd.DataFrame, nan: float = -999.) -> list:
    '''
    利用多输出决策树获得最优分箱的边界值列表，并将异常值单独分类
    '''
    # 定义异常值的标准
    z = np.abs((x - x.mean()) / x.std())
    outlier_idx = z > 5

    # 保留原始x的值用于后续分箱
    original_x = x.copy()

    # 用nan替换异常值
    x[outlier_idx] = nan

    # 多输出决策树分箱
    boundary = []  
    x = x.fillna(nan).values.reshape(-1, 1)
    y = y.values

    # 使用多输出决策树
    clf = MultiOutputClassifier(DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=2, min_samples_leaf=0.05))
    clf.fit(x, y)

    # 提取所有树的阈值
    for estimator in clf.estimators_:
        thresholds = estimator.tree_.threshold
        thresholds = thresholds[thresholds != -2]
        boundary.extend(thresholds)

    boundary = list(set(boundary))  # 移除重复的阈值
    boundary.sort()

    min_x = original_x.min()
    max_x = original_x.max() + 0.1  
    boundary = [min_x] + boundary + [max_x]

    # 将异常值作为单独的类别
    boundary = [-np.inf] + boundary + [np.inf]

    return boundary

# %%
data.columns
# Out:
# Index(['PtAge', 'WBC', 'RBC', 'HGB', 'HCT', 'MCV', 'MCH', 'MCHC', 'PLT',
#        'RDW-SD',
#        ...
#        'HFLC1_div_HFLC2', 'HFLC1_div_NRBC#', 'HFLC1_div_NRBC%',
#        'HFLC2_div_NRBC#', 'HFLC2_div_NRBC%', 'NRBC#_div_NRBC%', 'FYZ-IgM',
#        '甲流', 'Diagnosis', 'diagnosis_tokenized'],
#       dtype='object', length=532)

# %%
X = data.drop(columns=['FYZ-IgM',
       '甲流', 'Diagnosis', 'diagnosis_tokenized'])
y = data[['FYZ-IgM',
       '甲流']]
# change flout in y to int
y = y.astype(int)
diag = data['diagnosis_tokenized']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=100)  # for example, consider top 100 features
X_tfidf = tfidf.fit_transform(diag).toarray()

# Convert to DataFrame for easier handling
X_tfidf = pd.DataFrame(X_tfidf, columns=tfidf.get_feature_names_out())

# %%
X_bin = X.copy()

# %%
# 计算相关系数矩阵
corr_matrix = X_bin.corr()

# 查看相关系数
print(corr_matrix)
# Out:
#                     PtAge       WBC       RBC       HGB       HCT       MCV  \
# PtAge            1.000000 -0.032829 -0.260234 -0.095101 -0.133501  0.237954
# WBC             -0.032829  1.000000  0.074602  0.054899  0.053395 -0.015950
# RBC             -0.260234  0.074602  1.000000  0.797058  0.853932 -0.197049
# HGB             -0.095101  0.054899  0.797058  1.000000  0.975853  0.363591
# HCT             -0.133501  0.053395  0.853932  0.975853  1.000000  0.310689
# ...                   ...       ...       ...       ...       ...       ...
# HFLC1_div_NRBC# -0.235446  0.129178 -0.028039 -0.108799 -0.109901 -0.147807
# HFLC1_div_NRBC% -0.235446  0.129178 -0.028040 -0.108799 -0.109901 -0.147807
# HFLC2_div_NRBC# -0.209427 -0.052978 -0.041245 -0.111658 -0.115879 -0.136016
# HFLC2_div_NRBC% -0.209426 -0.052977 -0.041246 -0.111658 -0.115879 -0.136016
# NRBC#_div_NRBC% -0.062587  0.116352 -0.095813 -0.053828 -0.119306 -0.040335
#
#                       MCH      MCHC       PLT    RDW-SD  ...  CRP_div_HFLC1  \
# PtAge            0.241246  0.101903 -0.233830  0.290189  ...       0.161775
# WBC             -0.003690  0.047421  0.362552  0.035286  ...       0.047162
# RBC             -0.151189  0.117688  0.049603 -0.342623  ...       0.001344
# HGB              0.449962  0.458379 -0.112138 -0.238482  ...       0.034214
# HCT              0.333433  0.297504 -0.080620 -0.201560  ...       0.026603
# ...                   ...       ...       ...       ...  ...            ...
# HFLC1_div_NRBC# -0.132722 -0.019354  0.196241 -0.047067  ...      -0.147397
# HFLC1_div_NRBC% -0.132721 -0.019353  0.196241 -0.047066  ...      -0.147396
# HFLC2_div_NRBC# -0.119013 -0.009855  0.098618 -0.039235  ...      -0.135846
# HFLC2_div_NRBC% -0.119013 -0.009854  0.098619 -0.039235  ...      -0.135844
# NRBC#_div_NRBC%  0.058645  0.217246  0.145781  0.155212  ...      -0.124596
#
#                  CRP_div_HFLC2  CRP_div_NRBC#  CRP_div_NRBC%  HFLC1_div_HFLC2  \
# PtAge                 0.139532       0.242021       0.242019         0.026219
# WBC                   0.155063       0.238901       0.238900         0.241620
# RBC                   0.015849      -0.070542      -0.070543         0.018053
# HGB                   0.036510       0.006659       0.006658         0.020928
# HCT                   0.033087      -0.037729      -0.037730         0.015529
# ...                        ...            ...            ...              ...
# HFLC1_div_NRBC#      -0.122207       0.091898       0.091901        -0.016554
# HFLC1_div_NRBC%      -0.122206       0.091900       0.091902        -0.016554
# HFLC2_div_NRBC#      -0.128032       0.060609       0.060612        -0.037380
# HFLC2_div_NRBC%      -0.128031       0.060611       0.060614        -0.037380
# NRBC#_div_NRBC%      -0.144439       0.409458       0.409466         0.048809
#
#                  HFLC1_div_NRBC#  HFLC1_div_NRBC%  HFLC2_div_NRBC#  \
# PtAge                  -0.235446        -0.235446        -0.209427
# WBC                     0.129178         0.129178        -0.052978
# RBC                    -0.028039        -0.028040        -0.041245
# HGB                    -0.108799        -0.108799        -0.111658
# HCT                    -0.109901        -0.109901        -0.115879
# ...                          ...              ...              ...
# HFLC1_div_NRBC#         1.000000         1.000000         0.897138
# HFLC1_div_NRBC%         1.000000         1.000000         0.897138
# HFLC2_div_NRBC#         0.897138         0.897138         1.000000
# HFLC2_div_NRBC%         0.897138         0.897138         1.000000
# NRBC#_div_NRBC%         0.325193         0.325196         0.324523
#
#                  HFLC2_div_NRBC%  NRBC#_div_NRBC%
# PtAge                  -0.209426        -0.062587
# WBC                    -0.052977         0.116352
# RBC                    -0.041246        -0.095813
# HGB                    -0.111658        -0.053828
# HCT                    -0.115879        -0.119306
# ...                          ...              ...
# HFLC1_div_NRBC#         0.897138         0.325193
# HFLC1_div_NRBC%         0.897138         0.325196
# HFLC2_div_NRBC#         1.000000         0.324523
# HFLC2_div_NRBC%         1.000000         0.324526
# NRBC#_div_NRBC%         0.324526         1.000000
#
# [528 rows x 528 columns]

# %%
import pandas as pd
from scipy import stats

feature_columns = X_bin.columns
label_columns = y.columns

significant_features = {label: [] for label in label_columns}

df = pd.concat([X_bin, y], axis=1)

for label in label_columns:
    group1 = df[df[label] == 1]  # 有该标签的样本
    group2 = df[df[label] == 0]  # 没有该标签的样本

    for feature in feature_columns:
        f_value, p_value = stats.f_oneway(group1[feature], group2[feature])
        if p_value < 0.05:
            print(f"Feature '{feature}' shows significant difference for label '{label}' (p-value: {p_value})")
            significant_features[label].append(feature)
# Out:
# Feature 'PtAge' shows significant difference for label 'FYZ-IgM' (p-value: 0.0)
# Feature 'WBC' shows significant difference for label 'FYZ-IgM' (p-value: 3.9658980380158064e-18)
# Feature 'HGB' shows significant difference for label 'FYZ-IgM' (p-value: 1.5722369618276865e-28)
# Feature 'HCT' shows significant difference for label 'FYZ-IgM' (p-value: 1.1016619744455791e-18)
# Feature 'MCV' shows significant difference for label 'FYZ-IgM' (p-value: 2.1602142541283508e-57)
# Feature 'MCH' shows significant difference for label 'FYZ-IgM' (p-value: 1.7935865828931023e-70)
# Feature 'MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 1.8601859148291144e-21)
# Feature 'PLT' shows significant difference for label 'FYZ-IgM' (p-value: 3.212600893679424e-113)
# Feature 'RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 3.0183558374904834e-10)
# Feature 'RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 1.834264049696312e-07)
# Feature 'PDW' shows significant difference for label 'FYZ-IgM' (p-value: 1.8877675058394343e-54)
# Feature 'MPV' shows significant difference for label 'FYZ-IgM' (p-value: 1.7942141892345427e-30)
# Feature 'P-LCR' shows significant difference for label 'FYZ-IgM' (p-value: 1.0940022775647294e-22)
# Feature 'PCT' shows significant difference for label 'FYZ-IgM' (p-value: 3.1796235201558823e-73)
# Feature 'LY' shows significant difference for label 'FYZ-IgM' (p-value: 2.6787768185081348e-244)
# Feature 'MONO' shows significant difference for label 'FYZ-IgM' (p-value: 8.286708546699527e-05)
# Feature 'EO' shows significant difference for label 'FYZ-IgM' (p-value: 3.5422958632239795e-86)
# Feature 'BASO' shows significant difference for label 'FYZ-IgM' (p-value: 6.669786234469317e-48)
# Feature 'NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.3347667283355147e-91)
# Feature 'LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 3.5916153686176896e-158)
# Feature 'MONO%' shows significant difference for label 'FYZ-IgM' (p-value: 7.35912709073709e-47)
# Feature 'EO%' shows significant difference for label 'FYZ-IgM' (p-value: 3.352261799499511e-63)
# Feature 'BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.3872006751233182e-63)
# Feature 'IG#' shows significant difference for label 'FYZ-IgM' (p-value: 0.00298181513331643)
# Feature 'IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.1013153263059952e-06)
# Feature 'CRP' shows significant difference for label 'FYZ-IgM' (p-value: 7.843201978151019e-43)
# Feature 'HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.1134404786950853e-158)
# Feature 'HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 3.556344824501186e-138)
# Feature 'NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 0.012984131860895072)
# Feature 'NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 0.009215911187001765)
# Feature 'PtAge_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 2.1619551603136905e-29)
# Feature 'PtAge_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.4115632648034653e-27)
# Feature 'PtAge_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 8.783750944566542e-08)
# Feature 'PtAge_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 4.173442120033526e-05)
# Feature 'PtAge_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 6.225971388086439e-64)
# Feature 'PtAge_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.20145105452985e-53)
# Feature 'PtAge_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.444615029658166e-58)
# Feature 'PtAge_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.4591393427613635e-58)
# Feature 'WBC_div_RBC' shows significant difference for label 'FYZ-IgM' (p-value: 2.4157294538371397e-12)
# Feature 'WBC_div_HGB' shows significant difference for label 'FYZ-IgM' (p-value: 3.040247954103666e-15)
# Feature 'WBC_div_HCT' shows significant difference for label 'FYZ-IgM' (p-value: 1.8272759193280446e-20)
# Feature 'WBC_div_MCV' shows significant difference for label 'FYZ-IgM' (p-value: 3.155503664518643e-22)
# Feature 'WBC_div_MCH' shows significant difference for label 'FYZ-IgM' (p-value: 1.8513066076991291e-32)
# Feature 'WBC_div_MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 0.0006814626378406173)
# Feature 'WBC_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 0.000108313638737312)
# Feature 'WBC_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 5.666436641632626e-23)
# Feature 'WBC_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 2.29132572862721e-13)
# Feature 'WBC_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 7.968510284427287e-38)
# Feature 'WBC_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 3.924864233671758e-67)
# Feature 'WBC_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 1.2166474681217944e-09)
# Feature 'WBC_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.1041336158437057e-77)
# Feature 'WBC_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.467717860003884e-34)
# Feature 'WBC_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 7.425541511558282e-19)
# Feature 'WBC_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.1757647660980418e-08)
# Feature 'WBC_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6411835468429208e-74)
# Feature 'WBC_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 5.209327500284582e-31)
# Feature 'WBC_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 5.310738346499515e-33)
# Feature 'WBC_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.140439832619566e-46)
# Feature 'WBC_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 6.884261995479383e-36)
# Feature 'WBC_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 3.461720897443287e-81)
# Feature 'WBC_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.459087609151238e-81)
# Feature 'RBC_div_HCT' shows significant difference for label 'FYZ-IgM' (p-value: 1.6079961380032274e-07)
# Feature 'RBC_div_MCH' shows significant difference for label 'FYZ-IgM' (p-value: 2.033519536945881e-11)
# Feature 'RBC_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 2.3195526408585787e-12)
# Feature 'RBC_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 8.853827013429152e-06)
# Feature 'RBC_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 0.00411929772109781)
# Feature 'RBC_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 7.655309360909056e-104)
# Feature 'RBC_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 3.558680348810357e-13)
# Feature 'RBC_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 5.609071817121167e-91)
# Feature 'RBC_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.7854734603497285e-25)
# Feature 'RBC_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 2.6993325571717037e-67)
# Feature 'RBC_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 3.0206868497289643e-13)
# Feature 'RBC_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 7.355848602699154e-93)
# Feature 'RBC_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 3.111661079633149e-11)
# Feature 'RBC_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 2.3411764548939873e-13)
# Feature 'RBC_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.6176954410841794e-55)
# Feature 'RBC_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 1.8937769657988452e-45)
# Feature 'RBC_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 5.049175859858582e-75)
# Feature 'RBC_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 5.048777722186647e-75)
# Feature 'HGB_div_HCT' shows significant difference for label 'FYZ-IgM' (p-value: 2.0252059195422998e-25)
# Feature 'HGB_div_MCV' shows significant difference for label 'FYZ-IgM' (p-value: 0.002060106581678336)
# Feature 'HGB_div_MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 7.139704434145097e-20)
# Feature 'HGB_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 3.115302984145306e-68)
# Feature 'HGB_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 1.5105418305099725e-08)
# Feature 'HGB_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 3.5776311518581985e-31)
# Feature 'HGB_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 1.656970041512827e-115)
# Feature 'HGB_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 2.3556982247504497e-14)
# Feature 'HGB_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 2.655680695194917e-80)
# Feature 'HGB_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 2.203030133623642e-21)
# Feature 'HGB_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 4.689441716388493e-77)
# Feature 'HGB_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.498326762207483e-14)
# Feature 'HGB_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 9.822403031689157e-83)
# Feature 'HGB_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 3.816097091096489e-09)
# Feature 'HGB_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 2.5370168588423842e-11)
# Feature 'HGB_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.384495467665e-56)
# Feature 'HGB_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.306068880242121e-46)
# Feature 'HGB_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.5286126788497682e-53)
# Feature 'HGB_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.526579731305265e-53)
# Feature 'HCT_div_MCH' shows significant difference for label 'FYZ-IgM' (p-value: 0.0023852705840237275)
# Feature 'HCT_div_MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 3.5083746699045813e-06)
# Feature 'HCT_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 8.399823192489367e-62)
# Feature 'HCT_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 0.0001965655951513876)
# Feature 'HCT_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 1.9708602968324314e-24)
# Feature 'HCT_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 4.079584112585016e-113)
# Feature 'HCT_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 4.641483734761487e-14)
# Feature 'HCT_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 5.368286638611376e-84)
# Feature 'HCT_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 3.138921917266199e-24)
# Feature 'HCT_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 8.044129551917299e-75)
# Feature 'HCT_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 4.8689511670618416e-14)
# Feature 'HCT_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 3.861822514544249e-86)
# Feature 'HCT_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.3704893739932477e-09)
# Feature 'HCT_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.1129529712966634e-11)
# Feature 'HCT_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.656049066630775e-56)
# Feature 'HCT_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 8.845222659711572e-46)
# Feature 'HCT_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 3.355491823558642e-60)
# Feature 'HCT_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.352234800242441e-60)
# Feature 'MCV_div_MCH' shows significant difference for label 'FYZ-IgM' (p-value: 1.5885610429118135e-29)
# Feature 'MCV_div_MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 6.767515179531532e-21)
# Feature 'MCV_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 5.75581572173963e-42)
# Feature 'MCV_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 9.837763393561176e-09)
# Feature 'MCV_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 7.584665860969227e-40)
# Feature 'MCV_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 7.324177827873117e-105)
# Feature 'MCV_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 1.2561281890837723e-14)
# Feature 'MCV_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 7.595792460386298e-82)
# Feature 'MCV_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0178492559786503e-24)
# Feature 'MCV_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6367178505905275e-73)
# Feature 'MCV_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.2783196615846053e-14)
# Feature 'MCV_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 9.006619897944482e-85)
# Feature 'MCV_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.3870263426942972e-09)
# Feature 'MCV_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 6.726204067045185e-12)
# Feature 'MCV_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.473485009491407e-56)
# Feature 'MCV_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 9.025285695056074e-46)
# Feature 'MCV_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 9.670941657068202e-59)
# Feature 'MCV_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 9.661820551238322e-59)
# Feature 'MCH_div_MCHC' shows significant difference for label 'FYZ-IgM' (p-value: 2.767334190963708e-09)
# Feature 'MCH_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 3.1787741700070494e-45)
# Feature 'MCH_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 1.8941125899421863e-18)
# Feature 'MCH_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 2.2090602033702334e-49)
# Feature 'MCH_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 5.290041554430942e-107)
# Feature 'MCH_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 5.999977073698823e-15)
# Feature 'MCH_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 3.4901681278255545e-78)
# Feature 'MCH_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.943857702721603e-21)
# Feature 'MCH_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 8.262629499084003e-76)
# Feature 'MCH_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 6.168037947176316e-15)
# Feature 'MCH_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.0556106566032068e-81)
# Feature 'MCH_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 3.830459323944261e-09)
# Feature 'MCH_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.4700098459794702e-11)
# Feature 'MCH_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.6610955441746732e-56)
# Feature 'MCH_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.260321852870613e-46)
# Feature 'MCH_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 3.8773510450283895e-52)
# Feature 'MCH_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.87231984993875e-52)
# Feature 'MCHC_div_PLT' shows significant difference for label 'FYZ-IgM' (p-value: 2.0956822339419668e-36)
# Feature 'MCHC_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 0.003929577214258726)
# Feature 'MCHC_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 1.0207256648580896e-19)
# Feature 'MCHC_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 0.013422185249554843)
# Feature 'MCHC_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 6.622948849107627e-100)
# Feature 'MCHC_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 4.2560830428779923e-14)
# Feature 'MCHC_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.4731615318493604e-85)
# Feature 'MCHC_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 6.107949571708876e-35)
# Feature 'MCHC_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 2.7516532044372736e-69)
# Feature 'MCHC_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 3.277400180794786e-14)
# Feature 'MCHC_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.3327048978164925e-88)
# Feature 'MCHC_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 7.58887242116348e-11)
# Feature 'MCHC_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 2.498065654910285e-13)
# Feature 'MCHC_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.3212228582517497e-56)
# Feature 'MCHC_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.995509443654843e-46)
# Feature 'MCHC_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 8.079853269492004e-67)
# Feature 'MCHC_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 8.076196607606313e-67)
# Feature 'PLT_div_RDW-SD' shows significant difference for label 'FYZ-IgM' (p-value: 1.0986181140769348e-126)
# Feature 'PLT_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 5.968832718671062e-96)
# Feature 'PLT_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 9.169935424321909e-27)
# Feature 'PLT_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 1.0709101164135707e-53)
# Feature 'PLT_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 1.0105598087050989e-09)
# Feature 'PLT_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 4.553695985387035e-126)
# Feature 'PLT_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 2.6260974079815892e-166)
# Feature 'PLT_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 6.6130808451563135e-24)
# Feature 'PLT_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 8.59937982679916e-10)
# Feature 'PLT_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 9.480216522741243e-124)
# Feature 'PLT_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.1258988323105944e-23)
# Feature 'PLT_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 9.941224788875077e-26)
# Feature 'PLT_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.255770981009688e-45)
# Feature 'PLT_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 3.283750596428718e-36)
# Feature 'PLT_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 5.327835641497244e-153)
# Feature 'PLT_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 5.346675599181906e-153)
# Feature 'RDW-SD_div_RDW-CV' shows significant difference for label 'FYZ-IgM' (p-value: 1.7277731452454678e-61)
# Feature 'RDW-SD_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 0.038219568196877995)
# Feature 'RDW-SD_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 8.897651365675695e-95)
# Feature 'RDW-SD_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 4.601469881249527e-14)
# Feature 'RDW-SD_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.3817689476589658e-81)
# Feature 'RDW-SD_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 6.950880669614024e-26)
# Feature 'RDW-SD_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 1.190380165969817e-65)
# Feature 'RDW-SD_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 5.100672505803919e-14)
# Feature 'RDW-SD_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.2211347643111353e-84)
# Feature 'RDW-SD_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 5.82167023051715e-11)
# Feature 'RDW-SD_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.09814777271872e-13)
# Feature 'RDW-SD_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 5.962774030681025e-56)
# Feature 'RDW-SD_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 2.1830500736558274e-45)
# Feature 'RDW-SD_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.6656428209772008e-59)
# Feature 'RDW-SD_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6641885509702255e-59)
# Feature 'RDW-CV_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 0.0011384727113895453)
# Feature 'RDW-CV_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 1.3356939582286625e-84)
# Feature 'RDW-CV_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 6.422623108862939e-13)
# Feature 'RDW-CV_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 9.401977835197515e-89)
# Feature 'RDW-CV_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 9.162177223098006e-35)
# Feature 'RDW-CV_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 2.4413457381702112e-58)
# Feature 'RDW-CV_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 4.760594613000927e-13)
# Feature 'RDW-CV_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.3128743870206547e-91)
# Feature 'RDW-CV_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 7.44021638695566e-13)
# Feature 'RDW-CV_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 7.948033978704714e-16)
# Feature 'RDW-CV_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 6.673299856624467e-55)
# Feature 'RDW-CV_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 6.869360271658215e-45)
# Feature 'RDW-CV_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 7.142542792795797e-72)
# Feature 'RDW-CV_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 7.141436226062595e-72)
# Feature 'PDW_div_MPV' shows significant difference for label 'FYZ-IgM' (p-value: 1.216275521705945e-92)
# Feature 'PDW_div_P-LCR' shows significant difference for label 'FYZ-IgM' (p-value: 1.7544136537004695e-83)
# Feature 'PDW_div_PCT' shows significant difference for label 'FYZ-IgM' (p-value: 0.00012756531456722028)
# Feature 'PDW_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 1.5078443024445643e-09)
# Feature 'PDW_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 4.875029036467568e-62)
# Feature 'PDW_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 3.2702778635625896e-11)
# Feature 'PDW_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.572327726302228e-92)
# Feature 'PDW_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 1.4914906111878175e-89)
# Feature 'PDW_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 4.947203963935844e-42)
# Feature 'PDW_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6346700123723e-11)
# Feature 'PDW_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.7002226611916199e-96)
# Feature 'PDW_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 5.622060111815954e-19)
# Feature 'PDW_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 2.807337452334178e-25)
# Feature 'PDW_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.7416595827220682e-50)
# Feature 'PDW_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 2.37319918102475e-41)
# Feature 'PDW_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.0108298956835117e-70)
# Feature 'PDW_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0107280360565128e-70)
# Feature 'MPV_div_P-LCR' shows significant difference for label 'FYZ-IgM' (p-value: 4.5595826053999075e-21)
# Feature 'MPV_div_PCT' shows significant difference for label 'FYZ-IgM' (p-value: 8.77851054526711e-31)
# Feature 'MPV_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 5.212999325579423e-101)
# Feature 'MPV_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 6.3930316244101176e-15)
# Feature 'MPV_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 2.6838410469882433e-76)
# Feature 'MPV_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 5.825483139370399e-16)
# Feature 'MPV_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 1.2161480690174136e-71)
# Feature 'MPV_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 7.600057724325654e-15)
# Feature 'MPV_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.0916826008800183e-79)
# Feature 'MPV_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.1770339881837162e-08)
# Feature 'MPV_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.025766352068673e-10)
# Feature 'MPV_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 7.901215985646135e-56)
# Feature 'MPV_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 1.8382886457635044e-45)
# Feature 'MPV_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 3.768993557635072e-57)
# Feature 'MPV_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.764999334616176e-57)
# Feature 'P-LCR_div_PCT' shows significant difference for label 'FYZ-IgM' (p-value: 2.6564617603957234e-19)
# Feature 'P-LCR_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 4.139568991655248e-84)
# Feature 'P-LCR_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 7.593266172630047e-16)
# Feature 'P-LCR_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.6336217995327766e-51)
# Feature 'P-LCR_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 0.0008331280339275562)
# Feature 'P-LCR_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 3.317314930341217e-61)
# Feature 'P-LCR_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.778731239975571e-15)
# Feature 'P-LCR_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 6.658615893236304e-55)
# Feature 'P-LCR_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 9.868183122757156e-06)
# Feature 'P-LCR_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.1623795983581656e-07)
# Feature 'P-LCR_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.126526612529147e-51)
# Feature 'P-LCR_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 3.004764727576074e-42)
# Feature 'P-LCR_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 7.929792715719394e-28)
# Feature 'P-LCR_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 7.911974367382288e-28)
# Feature 'PCT_div_NEUT' shows significant difference for label 'FYZ-IgM' (p-value: 1.517073891617993e-15)
# Feature 'PCT_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 2.7978086781667123e-64)
# Feature 'PCT_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 4.8551751845369014e-11)
# Feature 'PCT_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.3730970319736522e-115)
# Feature 'PCT_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 3.320756878638898e-11)
# Feature 'PCT_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 6.206158495829437e-11)
# Feature 'PCT_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 4.413616492563317e-114)
# Feature 'PCT_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 9.773465572061117e-20)
# Feature 'PCT_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.1951817580150739e-21)
# Feature 'PCT_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.316205851464541e-46)
# Feature 'PCT_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 7.333010005830342e-37)
# Feature 'PCT_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 4.1864750935630183e-135)
# Feature 'PCT_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 4.199079397015935e-135)
# Feature 'NEUT_div_LY' shows significant difference for label 'FYZ-IgM' (p-value: 8.698698327532342e-61)
# Feature 'NEUT_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 7.144385898850235e-10)
# Feature 'NEUT_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 1.1432903665489837e-50)
# Feature 'NEUT_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 2.018532266745509e-12)
# Feature 'NEUT_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 8.492856019365122e-21)
# Feature 'NEUT_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0181935154947604e-08)
# Feature 'NEUT_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 5.548600964394546e-49)
# Feature 'NEUT_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 9.824922199943708e-21)
# Feature 'NEUT_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.2834271349160308e-22)
# Feature 'NEUT_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 5.491690201448371e-44)
# Feature 'NEUT_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.66070048554851e-34)
# Feature 'NEUT_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 2.478312115165509e-30)
# Feature 'NEUT_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 2.4737185490901266e-30)
# Feature 'LY_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 0.0006939807818748396)
# Feature 'LY_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 4.532251369046703e-161)
# Feature 'LY_div_NEUT%' shows significant difference for label 'FYZ-IgM' (p-value: 9.919552635016844e-31)
# Feature 'LY_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0802943989230847e-12)
# Feature 'LY_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 0.0006574320773955956)
# Feature 'LY_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.8376533843118677e-155)
# Feature 'LY_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.0137247392173714e-54)
# Feature 'LY_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 2.511469665242319e-55)
# Feature 'LY_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.599482854851304e-33)
# Feature 'LY_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 5.354977157920932e-26)
# Feature 'LY_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 8.136850619877608e-297)
# Feature 'LY_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 8.171074459588755e-297)
# Feature 'MONO_div_EO' shows significant difference for label 'FYZ-IgM' (p-value: 7.261178710334905e-07)
# Feature 'MONO_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 2.0369389556076197e-20)
# Feature 'MONO_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 9.177775672090269e-22)
# Feature 'MONO_div_MONO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.45431350837286e-11)
# Feature 'MONO_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.4302575889107084e-06)
# Feature 'MONO_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 6.662650717509179e-19)
# Feature 'MONO_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 4.276940573066338e-11)
# Feature 'MONO_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6759288847129017e-13)
# Feature 'MONO_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.0139094006877695e-49)
# Feature 'MONO_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 1.3664430130825369e-39)
# Feature 'MONO_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 5.013701233475029e-43)
# Feature 'MONO_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 5.000985166443251e-43)
# Feature 'EO_div_BASO' shows significant difference for label 'FYZ-IgM' (p-value: 6.474511255507518e-86)
# Feature 'EO_div_MONO%' shows significant difference for label 'FYZ-IgM' (p-value: 8.441464503193551e-35)
# Feature 'EO_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 9.012460153898988e-85)
# Feature 'EO_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 7.894245304438276e-37)
# Feature 'EO_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 1.6825258459832788e-41)
# Feature 'EO_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 1.2411599058963985e-12)
# Feature 'EO_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 3.92763425991183e-11)
# Feature 'EO_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 4.178611393314978e-131)
# Feature 'EO_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 4.173324639339868e-131)
# Feature 'BASO_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 0.027422656200210983)
# Feature 'BASO_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.3252905664237757e-14)
# Feature 'BASO_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 9.498176043099194e-40)
# Feature 'BASO_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 1.0134990760559487e-31)
# Feature 'NEUT%_div_LYBL%' shows significant difference for label 'FYZ-IgM' (p-value: 1.2258911689854041e-60)
# Feature 'NEUT%_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0344151773934911e-14)
# Feature 'NEUT%_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 2.690871255210809e-58)
# Feature 'NEUT%_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 4.1290848631814826e-06)
# Feature 'NEUT%_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 6.238107027127454e-08)
# Feature 'NEUT%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 9.586717310618842e-56)
# Feature 'NEUT%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 4.096500523121873e-46)
# Feature 'NEUT%_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 2.7186749511283616e-23)
# Feature 'NEUT%_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 2.7125126897139093e-23)
# Feature 'LYBL%_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 8.904564690033604e-06)
# Feature 'LYBL%_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 4.067736998919047e-155)
# Feature 'LYBL%_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 1.1900728433335297e-27)
# Feature 'LYBL%_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 3.518235546804224e-30)
# Feature 'LYBL%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.570591982245242e-35)
# Feature 'LYBL%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 9.27416581747144e-28)
# Feature 'LYBL%_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 3.780608191040421e-231)
# Feature 'LYBL%_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.793792765765068e-231)
# Feature 'MONO%_div_EO%' shows significant difference for label 'FYZ-IgM' (p-value: 7.929130088398736e-14)
# Feature 'MONO%_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 4.345837804883055e-59)
# Feature 'MONO%_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 0.010380609024043842)
# Feature 'MONO%_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 0.0004998902212534716)
# Feature 'MONO%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 5.420184329067746e-50)
# Feature 'MONO%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 2.3772756522115754e-39)
# Feature 'MONO%_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.3095689937913252e-22)
# Feature 'MONO%_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.3055965568808901e-22)
# Feature 'EO%_div_BASO%' shows significant difference for label 'FYZ-IgM' (p-value: 6.8152050108725e-90)
# Feature 'EO%_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 7.887204777025218e-23)
# Feature 'EO%_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 9.615185743066549e-33)
# Feature 'EO%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.983428254385661e-13)
# Feature 'EO%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 4.2121973977781646e-11)
# Feature 'EO%_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.0696512571647324e-111)
# Feature 'EO%_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.0682256776302035e-111)
# Feature 'BASO%_div_IG#' shows significant difference for label 'FYZ-IgM' (p-value: 0.02909153028402732)
# Feature 'BASO%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 4.627261645112094e-40)
# Feature 'BASO%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 8.349288828187878e-32)
# Feature 'IG#_div_IG%' shows significant difference for label 'FYZ-IgM' (p-value: 9.357180593125167e-16)
# Feature 'IG#_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 2.970540023348796e-21)
# Feature 'IG#_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 1.3696341436782245e-18)
# Feature 'IG%_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.1006703795868692e-21)
# Feature 'IG%_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 6.1645631626772664e-18)
# Feature 'CRP_div_HFLC1' shows significant difference for label 'FYZ-IgM' (p-value: 3.0317578392808284e-28)
# Feature 'CRP_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 7.083885539463704e-23)
# Feature 'CRP_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.8689151435964246e-13)
# Feature 'CRP_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.8718112988789873e-13)
# Feature 'HFLC1_div_HFLC2' shows significant difference for label 'FYZ-IgM' (p-value: 0.041626340538868815)
# Feature 'HFLC1_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 1.2690718526062482e-203)
# Feature 'HFLC1_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 1.2686118216073852e-203)
# Feature 'HFLC2_div_NRBC#' shows significant difference for label 'FYZ-IgM' (p-value: 9.841598862243858e-167)
# Feature 'HFLC2_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 9.83726092351288e-167)
# Feature 'NRBC#_div_NRBC%' shows significant difference for label 'FYZ-IgM' (p-value: 3.3440236553820036e-74)
# Feature 'PtAge' shows significant difference for label '甲流' (p-value: 4.1484776327138624e-33)
# Feature 'WBC' shows significant difference for label '甲流' (p-value: 2.2169365117201844e-47)
# Feature 'HGB' shows significant difference for label '甲流' (p-value: 0.00500336104067574)
# Feature 'HCT' shows significant difference for label '甲流' (p-value: 0.0008934084506533116)
# Feature 'MCV' shows significant difference for label '甲流' (p-value: 1.6809970970309774e-11)
# Feature 'MCH' shows significant difference for label '甲流' (p-value: 5.340523430377009e-07)
# Feature 'MCHC' shows significant difference for label '甲流' (p-value: 0.014427652490583453)
# Feature 'PLT' shows significant difference for label '甲流' (p-value: 5.37788157356941e-60)
# Feature 'RDW-SD' shows significant difference for label '甲流' (p-value: 0.006252513931686228)
# Feature 'RDW-CV' shows significant difference for label '甲流' (p-value: 1.2087864524668106e-06)
# Feature 'PDW' shows significant difference for label '甲流' (p-value: 7.279773700010965e-100)
# Feature 'MPV' shows significant difference for label '甲流' (p-value: 4.40766850748527e-28)
# Feature 'P-LCR' shows significant difference for label '甲流' (p-value: 1.5773396396391233e-15)
# Feature 'PCT' shows significant difference for label '甲流' (p-value: 2.9845949824806752e-34)
# Feature 'NEUT' shows significant difference for label '甲流' (p-value: 5.566576510647272e-23)
# Feature 'LY' shows significant difference for label '甲流' (p-value: 5.917090981444541e-112)
# Feature 'MONO' shows significant difference for label '甲流' (p-value: 1.6354449095933121e-09)
# Feature 'EO' shows significant difference for label '甲流' (p-value: 2.0191891776477497e-48)
# Feature 'BASO' shows significant difference for label '甲流' (p-value: 8.932016086209075e-10)
# Feature 'NEUT%' shows significant difference for label '甲流' (p-value: 1.8592838110507746e-19)
# Feature 'LYBL%' shows significant difference for label '甲流' (p-value: 1.3016248351323932e-60)
# Feature 'MONO%' shows significant difference for label '甲流' (p-value: 4.0984774252523403e-94)
# Feature 'EO%' shows significant difference for label '甲流' (p-value: 1.0766420335258866e-38)
# Feature 'BASO%' shows significant difference for label '甲流' (p-value: 1.7004422833648116e-27)
# Feature 'HFLC1' shows significant difference for label '甲流' (p-value: 1.1441479995746194e-43)
# Feature 'HFLC2' shows significant difference for label '甲流' (p-value: 7.365236463610313e-38)
# Feature 'NRBC#' shows significant difference for label '甲流' (p-value: 0.00011320716524304462)
# Feature 'NRBC%' shows significant difference for label '甲流' (p-value: 0.008773947888469679)
# Feature 'PtAge_div_WBC' shows significant difference for label '甲流' (p-value: 0.016661283175724774)
# Feature 'PtAge_div_RBC' shows significant difference for label '甲流' (p-value: 0.01666127369706644)
# Feature 'PtAge_div_HGB' shows significant difference for label '甲流' (p-value: 0.01666132451668263)
# Feature 'PtAge_div_HCT' shows significant difference for label '甲流' (p-value: 0.01666132050277971)
# Feature 'PtAge_div_MCV' shows significant difference for label '甲流' (p-value: 0.01666132410050204)
# Feature 'PtAge_div_MCH' shows significant difference for label '甲流' (p-value: 0.016661319628054918)
# Feature 'PtAge_div_MCHC' shows significant difference for label '甲流' (p-value: 0.01666132567107007)
# Feature 'PtAge_div_PLT' shows significant difference for label '甲流' (p-value: 0.016661324260173343)
# Feature 'PtAge_div_RDW-SD' shows significant difference for label '甲流' (p-value: 0.016661321887530167)
# Feature 'PtAge_div_RDW-CV' shows significant difference for label '甲流' (p-value: 0.016661310983690662)
# Feature 'PtAge_div_NEUT' shows significant difference for label '甲流' (p-value: 0.016661272661648005)
# Feature 'PtAge_div_LY' shows significant difference for label '甲流' (p-value: 0.016660921541336915)
# Feature 'PtAge_div_MONO' shows significant difference for label '甲流' (p-value: 0.015718386455062374)
# Feature 'PtAge_div_EO' shows significant difference for label '甲流' (p-value: 8.067870494345908e-24)
# Feature 'PtAge_div_NEUT%' shows significant difference for label '甲流' (p-value: 0.01666132344157707)
# Feature 'PtAge_div_LYBL%' shows significant difference for label '甲流' (p-value: 0.01666130664276747)
# Feature 'PtAge_div_MONO%' shows significant difference for label '甲流' (p-value: 0.015718469883281384)
# Feature 'PtAge_div_EO%' shows significant difference for label '甲流' (p-value: 1.6148825731511733e-24)
# Feature 'PtAge_div_IG#' shows significant difference for label '甲流' (p-value: 6.603995737302823e-05)
# Feature 'PtAge_div_IG%' shows significant difference for label '甲流' (p-value: 8.142625448487956e-07)
# Feature 'PtAge_div_HFLC1' shows significant difference for label '甲流' (p-value: 7.412526672417582e-18)
# Feature 'PtAge_div_HFLC2' shows significant difference for label '甲流' (p-value: 6.204890330745196e-16)
# Feature 'PtAge_div_NRBC#' shows significant difference for label '甲流' (p-value: 5.7324500191567255e-06)
# Feature 'PtAge_div_NRBC%' shows significant difference for label '甲流' (p-value: 5.723546071014259e-06)
# Feature 'WBC_div_RBC' shows significant difference for label '甲流' (p-value: 2.4500177861234535e-32)
# Feature 'WBC_div_HGB' shows significant difference for label '甲流' (p-value: 4.2554953386914495e-20)
# Feature 'WBC_div_HCT' shows significant difference for label '甲流' (p-value: 2.4477272499599526e-35)
# Feature 'WBC_div_MCV' shows significant difference for label '甲流' (p-value: 1.5772117222853861e-37)
# Feature 'WBC_div_MCH' shows significant difference for label '甲流' (p-value: 1.6593137180914855e-49)
# Feature 'WBC_div_MCHC' shows significant difference for label '甲流' (p-value: 1.4301521767506389e-05)
# Feature 'WBC_div_PLT' shows significant difference for label '甲流' (p-value: 0.008162795394745884)
# Feature 'WBC_div_RDW-SD' shows significant difference for label '甲流' (p-value: 3.031304662962259e-46)
# Feature 'WBC_div_RDW-CV' shows significant difference for label '甲流' (p-value: 4.645945691482716e-40)
# Feature 'WBC_div_NEUT' shows significant difference for label '甲流' (p-value: 5.134832245384851e-09)
# Feature 'WBC_div_LY' shows significant difference for label '甲流' (p-value: 8.095646056075138e-17)
# Feature 'WBC_div_EO' shows significant difference for label '甲流' (p-value: 3.240578954864816e-10)
# Feature 'WBC_div_BASO' shows significant difference for label '甲流' (p-value: 8.055678334090708e-28)
# Feature 'WBC_div_NEUT%' shows significant difference for label '甲流' (p-value: 5.61990181811375e-20)
# Feature 'WBC_div_EO%' shows significant difference for label '甲流' (p-value: 8.587635667251732e-10)
# Feature 'WBC_div_BASO%' shows significant difference for label '甲流' (p-value: 2.162886440720293e-26)
# Feature 'WBC_div_IG#' shows significant difference for label '甲流' (p-value: 0.012984376952607967)
# Feature 'WBC_div_IG%' shows significant difference for label '甲流' (p-value: 0.049768565794349885)
# Feature 'WBC_div_HFLC1' shows significant difference for label '甲流' (p-value: 2.5350414064511914e-11)
# Feature 'WBC_div_HFLC2' shows significant difference for label '甲流' (p-value: 6.227222742560085e-06)
# Feature 'WBC_div_NRBC#' shows significant difference for label '甲流' (p-value: 5.215940866870861e-144)
# Feature 'WBC_div_NRBC%' shows significant difference for label '甲流' (p-value: 5.216877422722062e-144)
# Feature 'RBC_div_MCHC' shows significant difference for label '甲流' (p-value: 0.016500604329061558)
# Feature 'RBC_div_PLT' shows significant difference for label '甲流' (p-value: 4.234306639695971e-13)
# Feature 'RBC_div_RDW-CV' shows significant difference for label '甲流' (p-value: 8.497088071454897e-06)
# Feature 'RBC_div_LY' shows significant difference for label '甲流' (p-value: 6.545603160856156e-72)
# Feature 'RBC_div_EO' shows significant difference for label '甲流' (p-value: 2.7956927525288487e-27)
# Feature 'RBC_div_BASO' shows significant difference for label '甲流' (p-value: 1.5204759509614953e-26)
# Feature 'RBC_div_NEUT%' shows significant difference for label '甲流' (p-value: 5.287369963375123e-05)
# Feature 'RBC_div_LYBL%' shows significant difference for label '甲流' (p-value: 8.050548611597963e-18)
# Feature 'RBC_div_EO%' shows significant difference for label '甲流' (p-value: 2.9237531401743896e-30)
# Feature 'RBC_div_BASO%' shows significant difference for label '甲流' (p-value: 2.811794973274833e-25)
# Feature 'RBC_div_HFLC1' shows significant difference for label '甲流' (p-value: 9.08737794079792e-29)
# Feature 'RBC_div_HFLC2' shows significant difference for label '甲流' (p-value: 1.77465140264621e-26)
# Feature 'RBC_div_NRBC#' shows significant difference for label '甲流' (p-value: 3.4704158316330756e-133)
# Feature 'RBC_div_NRBC%' shows significant difference for label '甲流' (p-value: 3.4699269485970294e-133)
# Feature 'HGB_div_HCT' shows significant difference for label '甲流' (p-value: 0.023559881359361393)
# ...
# Feature 'RDW-CV_div_NRBC%' shows significant difference for label '甲流' (p-value: 3.6493022346489844e-121)
# Feature 'PDW_div_MPV' shows significant difference for label '甲流' (p-value: 1.0232813671719695e-132)
# Feature 'PDW_div_P-LCR' shows significant difference for label '甲流' (p-value: 2.6327959412338558e-82)
# Feature 'PDW_div_NEUT' shows significant difference for label '甲流' (p-value: 3.925930179271944e-06)
# Feature 'PDW_div_LY' shows significant difference for label '甲流' (p-value: 4.561572177378599e-24)
# Feature 'PDW_div_EO' shows significant difference for label '甲流' (p-value: 1.8830470920647078e-17)
# Feature 'PDW_div_BASO' shows significant difference for label '甲流' (p-value: 4.977742098274951e-27)
# Feature 'PDW_div_NEUT%' shows significant difference for label '甲流' (p-value: 1.0445365863229924e-49)
# Feature 'PDW_div_LYBL%' shows significant difference for label '甲流' (p-value: 0.008086556737557999)
# Feature 'PDW_div_EO%' shows significant difference for label '甲流' (p-value: 3.2744848648919424e-20)
# Feature 'PDW_div_BASO%' shows significant difference for label '甲流' (p-value: 3.8962448776408547e-26)
# Feature 'PDW_div_IG#' shows significant difference for label '甲流' (p-value: 0.011947216375195921)
# Feature 'PDW_div_HFLC1' shows significant difference for label '甲流' (p-value: 6.270943597074639e-17)
# Feature 'PDW_div_HFLC2' shows significant difference for label '甲流' (p-value: 1.8047068780626612e-15)
# Feature 'PDW_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.3163332598700808e-127)
# Feature 'PDW_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.3160998008519923e-127)
# Feature 'MPV_div_P-LCR' shows significant difference for label '甲流' (p-value: 7.816513613622656e-11)
# Feature 'MPV_div_PCT' shows significant difference for label '甲流' (p-value: 1.1016036672797328e-27)
# Feature 'MPV_div_LY' shows significant difference for label '甲流' (p-value: 9.308016576895474e-75)
# Feature 'MPV_div_EO' shows significant difference for label '甲流' (p-value: 3.650955856432052e-30)
# Feature 'MPV_div_BASO' shows significant difference for label '甲流' (p-value: 1.88014791078548e-21)
# Feature 'MPV_div_LYBL%' shows significant difference for label '甲流' (p-value: 1.0525527035994244e-22)
# Feature 'MPV_div_EO%' shows significant difference for label '甲流' (p-value: 1.0105387340634948e-32)
# Feature 'MPV_div_BASO%' shows significant difference for label '甲流' (p-value: 1.2056654875068311e-20)
# Feature 'MPV_div_HFLC1' shows significant difference for label '甲流' (p-value: 1.2598009355621676e-29)
# Feature 'MPV_div_HFLC2' shows significant difference for label '甲流' (p-value: 1.1560669241322706e-27)
# Feature 'MPV_div_NRBC#' shows significant difference for label '甲流' (p-value: 2.488671615879959e-113)
# Feature 'MPV_div_NRBC%' shows significant difference for label '甲流' (p-value: 2.485202610883918e-113)
# Feature 'P-LCR_div_PCT' shows significant difference for label '甲流' (p-value: 2.5662310207704844e-19)
# Feature 'P-LCR_div_NEUT' shows significant difference for label '甲流' (p-value: 0.04020748792995161)
# Feature 'P-LCR_div_LY' shows significant difference for label '甲流' (p-value: 6.469761267120574e-66)
# Feature 'P-LCR_div_EO' shows significant difference for label '甲流' (p-value: 2.1632941256450854e-31)
# Feature 'P-LCR_div_BASO' shows significant difference for label '甲流' (p-value: 3.509504133659062e-14)
# Feature 'P-LCR_div_LYBL%' shows significant difference for label '甲流' (p-value: 6.412865429235371e-23)
# Feature 'P-LCR_div_EO%' shows significant difference for label '甲流' (p-value: 2.3050662611206623e-33)
# Feature 'P-LCR_div_BASO%' shows significant difference for label '甲流' (p-value: 7.429660235391725e-14)
# Feature 'P-LCR_div_IG%' shows significant difference for label '甲流' (p-value: 0.024787378826130507)
# Feature 'P-LCR_div_HFLC1' shows significant difference for label '甲流' (p-value: 7.62048024220879e-29)
# Feature 'P-LCR_div_HFLC2' shows significant difference for label '甲流' (p-value: 2.199914106423959e-27)
# Feature 'P-LCR_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.0202416329108125e-74)
# Feature 'P-LCR_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.016302597336142e-74)
# Feature 'PCT_div_NEUT' shows significant difference for label '甲流' (p-value: 0.032726302468268596)
# Feature 'PCT_div_LY' shows significant difference for label '甲流' (p-value: 5.154920324889864e-47)
# Feature 'PCT_div_EO' shows significant difference for label '甲流' (p-value: 1.898768130291321e-24)
# Feature 'PCT_div_BASO' shows significant difference for label '甲流' (p-value: 1.7403031090064711e-32)
# Feature 'PCT_div_LYBL%' shows significant difference for label '甲流' (p-value: 4.854243019352032e-05)
# Feature 'PCT_div_EO%' shows significant difference for label '甲流' (p-value: 3.9246557549584836e-26)
# Feature 'PCT_div_BASO%' shows significant difference for label '甲流' (p-value: 7.143340654367558e-31)
# Feature 'PCT_div_HFLC1' shows significant difference for label '甲流' (p-value: 1.8753643023410928e-19)
# Feature 'PCT_div_HFLC2' shows significant difference for label '甲流' (p-value: 6.499038209584013e-17)
# Feature 'PCT_div_NRBC#' shows significant difference for label '甲流' (p-value: 4.968725207385962e-158)
# Feature 'PCT_div_NRBC%' shows significant difference for label '甲流' (p-value: 4.973075646473906e-158)
# Feature 'NEUT_div_LY' shows significant difference for label '甲流' (p-value: 3.5733941446638667e-12)
# Feature 'NEUT_div_EO' shows significant difference for label '甲流' (p-value: 6.65661596576127e-08)
# Feature 'NEUT_div_BASO' shows significant difference for label '甲流' (p-value: 3.2665056464105075e-23)
# Feature 'NEUT_div_NEUT%' shows significant difference for label '甲流' (p-value: 6.2682253899575354e-30)
# Feature 'NEUT_div_EO%' shows significant difference for label '甲流' (p-value: 2.749943011011804e-07)
# Feature 'NEUT_div_BASO%' shows significant difference for label '甲流' (p-value: 1.706696203404713e-22)
# Feature 'NEUT_div_HFLC1' shows significant difference for label '甲流' (p-value: 4.7988925243940204e-09)
# Feature 'NEUT_div_HFLC2' shows significant difference for label '甲流' (p-value: 0.0004618262583156535)
# Feature 'NEUT_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.2870751471322343e-99)
# Feature 'NEUT_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.2851382025073804e-99)
# Feature 'LY_div_EO' shows significant difference for label '甲流' (p-value: 2.0134753267014653e-10)
# Feature 'LY_div_BASO' shows significant difference for label '甲流' (p-value: 3.983838882962162e-42)
# Feature 'LY_div_NEUT%' shows significant difference for label '甲流' (p-value: 3.926232758450595e-08)
# Feature 'LY_div_LYBL%' shows significant difference for label '甲流' (p-value: 6.203484051157229e-31)
# Feature 'LY_div_EO%' shows significant difference for label '甲流' (p-value: 7.852224446544072e-12)
# Feature 'LY_div_BASO%' shows significant difference for label '甲流' (p-value: 6.04086748792156e-39)
# Feature 'LY_div_IG#' shows significant difference for label '甲流' (p-value: 6.310127203334779e-11)
# Feature 'LY_div_IG%' shows significant difference for label '甲流' (p-value: 1.1248576928012279e-08)
# Feature 'LY_div_HFLC1' shows significant difference for label '甲流' (p-value: 5.83145487285112e-09)
# Feature 'LY_div_HFLC2' shows significant difference for label '甲流' (p-value: 3.553687142621739e-07)
# Feature 'LY_div_NRBC#' shows significant difference for label '甲流' (p-value: 2.0462610631469235e-189)
# Feature 'LY_div_NRBC%' shows significant difference for label '甲流' (p-value: 2.046239808012656e-189)
# Feature 'MONO_div_EO' shows significant difference for label '甲流' (p-value: 8.727527818986834e-15)
# Feature 'MONO_div_BASO' shows significant difference for label '甲流' (p-value: 0.00014519698017077955)
# Feature 'MONO_div_NEUT%' shows significant difference for label '甲流' (p-value: 0.00019101819214821243)
# Feature 'MONO_div_LYBL%' shows significant difference for label '甲流' (p-value: 4.576830717255182e-10)
# Feature 'MONO_div_MONO%' shows significant difference for label '甲流' (p-value: 6.516874049564528e-27)
# Feature 'MONO_div_EO%' shows significant difference for label '甲流' (p-value: 8.116423210377872e-15)
# Feature 'MONO_div_BASO%' shows significant difference for label '甲流' (p-value: 0.0004304429373261756)
# Feature 'MONO_div_IG%' shows significant difference for label '甲流' (p-value: 0.03477805018961953)
# Feature 'MONO_div_HFLC1' shows significant difference for label '甲流' (p-value: 2.3871958336193374e-34)
# Feature 'MONO_div_HFLC2' shows significant difference for label '甲流' (p-value: 4.5511178832637185e-27)
# Feature 'MONO_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.6169597059497572e-91)
# Feature 'MONO_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.6082087405732163e-91)
# Feature 'EO_div_BASO' shows significant difference for label '甲流' (p-value: 8.1088850989819385e-22)
# Feature 'EO_div_MONO%' shows significant difference for label '甲流' (p-value: 2.6764640216551877e-15)
# Feature 'EO_div_BASO%' shows significant difference for label '甲流' (p-value: 4.1647877546291913e-20)
# Feature 'EO_div_IG#' shows significant difference for label '甲流' (p-value: 5.5619704585628016e-11)
# Feature 'EO_div_IG%' shows significant difference for label '甲流' (p-value: 1.0557467315570115e-09)
# Feature 'EO_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.5248000983504643e-66)
# Feature 'EO_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.5243661513932693e-66)
# Feature 'BASO_div_NEUT%' shows significant difference for label '甲流' (p-value: 0.013672009536662345)
# Feature 'BASO_div_LYBL%' shows significant difference for label '甲流' (p-value: 0.0030190223061927184)
# Feature 'BASO_div_MONO%' shows significant difference for label '甲流' (p-value: 0.01560570861653992)
# Feature 'BASO_div_EO%' shows significant difference for label '甲流' (p-value: 4.012529209646176e-27)
# Feature 'BASO_div_IG#' shows significant difference for label '甲流' (p-value: 0.000637826420249682)
# Feature 'BASO_div_IG%' shows significant difference for label '甲流' (p-value: 7.280855067713994e-06)
# Feature 'BASO_div_HFLC1' shows significant difference for label '甲流' (p-value: 4.632161419302091e-18)
# Feature 'BASO_div_HFLC2' shows significant difference for label '甲流' (p-value: 5.434504770440158e-16)
# Feature 'BASO_div_NRBC#' shows significant difference for label '甲流' (p-value: 2.014332204539207e-33)
# Feature 'BASO_div_NRBC%' shows significant difference for label '甲流' (p-value: 2.0059113930958762e-33)
# Feature 'NEUT%_div_LYBL%' shows significant difference for label '甲流' (p-value: 4.164154619066176e-12)
# Feature 'NEUT%_div_EO%' shows significant difference for label '甲流' (p-value: 2.1981733026292654e-27)
# Feature 'NEUT%_div_BASO%' shows significant difference for label '甲流' (p-value: 5.935590769175394e-18)
# Feature 'NEUT%_div_IG%' shows significant difference for label '甲流' (p-value: 0.008989927115313108)
# Feature 'NEUT%_div_HFLC1' shows significant difference for label '甲流' (p-value: 1.3858850397272751e-25)
# Feature 'NEUT%_div_HFLC2' shows significant difference for label '甲流' (p-value: 2.796381521842426e-22)
# Feature 'NEUT%_div_NRBC#' shows significant difference for label '甲流' (p-value: 2.3689732048909765e-84)
# Feature 'NEUT%_div_NRBC%' shows significant difference for label '甲流' (p-value: 2.36223882385684e-84)
# Feature 'LYBL%_div_EO%' shows significant difference for label '甲流' (p-value: 4.322568094100677e-21)
# Feature 'LYBL%_div_BASO%' shows significant difference for label '甲流' (p-value: 6.042984716657366e-35)
# Feature 'LYBL%_div_IG#' shows significant difference for label '甲流' (p-value: 1.5678283294011357e-06)
# Feature 'LYBL%_div_IG%' shows significant difference for label '甲流' (p-value: 0.0003916076939326425)
# Feature 'LYBL%_div_HFLC1' shows significant difference for label '甲流' (p-value: 8.648851363089951e-16)
# Feature 'LYBL%_div_HFLC2' shows significant difference for label '甲流' (p-value: 8.604688632640113e-19)
# Feature 'LYBL%_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.061318536465633e-155)
# Feature 'LYBL%_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.0601879531346656e-155)
# Feature 'MONO%_div_EO%' shows significant difference for label '甲流' (p-value: 2.980626238297952e-44)
# Feature 'MONO%_div_BASO%' shows significant difference for label '甲流' (p-value: 5.004308467678299e-11)
# Feature 'MONO%_div_IG#' shows significant difference for label '甲流' (p-value: 0.003354655207780345)
# Feature 'MONO%_div_IG%' shows significant difference for label '甲流' (p-value: 1.8539082998806212e-05)
# Feature 'MONO%_div_HFLC1' shows significant difference for label '甲流' (p-value: 2.1854643095796938e-47)
# Feature 'MONO%_div_HFLC2' shows significant difference for label '甲流' (p-value: 4.54702186317093e-46)
# Feature 'MONO%_div_NRBC#' shows significant difference for label '甲流' (p-value: 7.256335701119213e-59)
# Feature 'MONO%_div_NRBC%' shows significant difference for label '甲流' (p-value: 7.203851872888884e-59)
# Feature 'EO%_div_BASO%' shows significant difference for label '甲流' (p-value: 1.4263129125445866e-20)
# Feature 'EO%_div_IG#' shows significant difference for label '甲流' (p-value: 1.797354191137496e-09)
# Feature 'EO%_div_IG%' shows significant difference for label '甲流' (p-value: 1.151256726478826e-07)
# Feature 'EO%_div_CRP' shows significant difference for label '甲流' (p-value: 0.034274742854564375)
# Feature 'EO%_div_HFLC2' shows significant difference for label '甲流' (p-value: 0.03935613264930396)
# Feature 'EO%_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.8469197955939768e-62)
# Feature 'EO%_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.8460406339911726e-62)
# Feature 'BASO%_div_IG#' shows significant difference for label '甲流' (p-value: 0.00030392571790842225)
# Feature 'BASO%_div_IG%' shows significant difference for label '甲流' (p-value: 3.921876133128903e-08)
# Feature 'BASO%_div_HFLC1' shows significant difference for label '甲流' (p-value: 9.178107289219641e-26)
# Feature 'BASO%_div_HFLC2' shows significant difference for label '甲流' (p-value: 8.726487093776365e-28)
# Feature 'BASO%_div_NRBC#' shows significant difference for label '甲流' (p-value: 3.29974890416473e-20)
# Feature 'BASO%_div_NRBC%' shows significant difference for label '甲流' (p-value: 3.285545648216722e-20)
# Feature 'IG#_div_HFLC1' shows significant difference for label '甲流' (p-value: 0.00800750849293627)
# Feature 'IG#_div_NRBC#' shows significant difference for label '甲流' (p-value: 0.01839594886627016)
# Feature 'IG#_div_NRBC%' shows significant difference for label '甲流' (p-value: 0.018393264524310993)
# Feature 'IG%_div_HFLC1' shows significant difference for label '甲流' (p-value: 2.0463386081409515e-05)
# Feature 'IG%_div_HFLC2' shows significant difference for label '甲流' (p-value: 0.000208606973608593)
# Feature 'IG%_div_NRBC#' shows significant difference for label '甲流' (p-value: 3.1505643497169945e-06)
# Feature 'IG%_div_NRBC%' shows significant difference for label '甲流' (p-value: 3.148317301969173e-06)
# Feature 'CRP_div_HFLC1' shows significant difference for label '甲流' (p-value: 1.91852631121748e-09)
# Feature 'CRP_div_HFLC2' shows significant difference for label '甲流' (p-value: 0.00013337250654493692)
# Feature 'CRP_div_NRBC#' shows significant difference for label '甲流' (p-value: 4.3148000348070203e-10)
# Feature 'CRP_div_NRBC%' shows significant difference for label '甲流' (p-value: 4.30987856618964e-10)
# Feature 'HFLC1_div_HFLC2' shows significant difference for label '甲流' (p-value: 6.1221291222139315e-06)
# Feature 'HFLC1_div_NRBC#' shows significant difference for label '甲流' (p-value: 1.4435258188732477e-64)
# Feature 'HFLC1_div_NRBC%' shows significant difference for label '甲流' (p-value: 1.442578635222863e-64)
# Feature 'HFLC2_div_NRBC#' shows significant difference for label '甲流' (p-value: 2.5215175085843277e-54)
# Feature 'HFLC2_div_NRBC%' shows significant difference for label '甲流' (p-value: 2.519812889239912e-54)
# Feature 'NRBC#_div_NRBC%' shows significant difference for label '甲流' (p-value: 6.880948072954038e-129)

# %%
significant_features_union = set().union(*significant_features.values())
# save significant features to csv
pd.DataFrame(significant_features_union).to_csv('../data/curated/significant_features.csv')

# %%
from sklearn.feature_selection import mutual_info_classif

mi_scores = np.zeros((X_bin.shape[1], y.shape[1]))  # 初始化互信息分数矩阵

for i in range(y.shape[1]):
    mi_scores[:, i] = mutual_info_classif(X_bin, y.iloc[:, i])

# %%
# 设置相关性阈值
threshold = 0.7

# 找到高度相关的特征对
high_corr = set()
for i in range(len(corr_matrix.columns)):
    for j in range(i):
        if abs(corr_matrix.iloc[i, j]) > threshold:
            colname = corr_matrix.columns[j]
            high_corr.add(colname)

high_corr
# Out:
# {'BASO',
#  'BASO%_div_HFLC1',
#  'BASO%_div_IG#',
#  'BASO%_div_IG%',
#  'BASO%_div_NRBC#',
#  'BASO_div_CRP',
#  'BASO_div_EO%',
#  'BASO_div_HFLC1',
#  'BASO_div_HFLC2',
#  'BASO_div_IG#',
#  'BASO_div_IG%',
#  'BASO_div_LYBL%',
#  'BASO_div_NEUT%',
#  'BASO_div_NRBC#',
#  'BASO_div_NRBC%',
#  'CRP',
#  'CRP_div_HFLC1',
#  'CRP_div_NRBC#',
#  'EO',
#  'EO%',
#  'EO%_div_HFLC1',
#  'EO%_div_IG#',
#  'EO%_div_NRBC#',
#  'EO_div_BASO',
#  'EO_div_BASO%',
#  'EO_div_CRP',
#  'EO_div_HFLC1',
#  'EO_div_HFLC2',
#  'EO_div_IG#',
#  'EO_div_IG%',
#  'EO_div_LYBL%',
#  'EO_div_MONO%',
#  'EO_div_NEUT%',
#  'EO_div_NRBC#',
#  'EO_div_NRBC%',
#  'HCT',
#  'HCT_div_BASO',
#  'HCT_div_BASO%',
#  'HCT_div_CRP',
#  'HCT_div_EO',
#  'HCT_div_EO%',
#  'HCT_div_HFLC1',
#  'HCT_div_HFLC2',
#  'HCT_div_IG#',
#  'HCT_div_IG%',
#  'HCT_div_LY',
#  'HCT_div_LYBL%',
#  'HCT_div_MCH',
#  'HCT_div_MCHC',
#  'HCT_div_MCV',
#  'HCT_div_MONO',
#  'HCT_div_MONO%',
#  'HCT_div_MPV',
#  'HCT_div_NEUT',
#  'HCT_div_NEUT%',
#  'HCT_div_NRBC#',
#  'HCT_div_NRBC%',
#  'HCT_div_P-LCR',
#  'HCT_div_PCT',
#  'HCT_div_PDW',
#  'HCT_div_PLT',
#  'HCT_div_RDW-CV',
#  'HCT_div_RDW-SD',
#  'HFLC1',
#  'HFLC1_div_NRBC#',
#  'HFLC1_div_NRBC%',
#  'HFLC2',
#  'HFLC2_div_NRBC#',
#  'HGB',
#  'HGB_div_BASO',
#  'HGB_div_BASO%',
#  'HGB_div_CRP',
#  'HGB_div_EO',
#  'HGB_div_EO%',
#  'HGB_div_HFLC1',
#  'HGB_div_HFLC2',
#  'HGB_div_IG#',
#  'HGB_div_IG%',
#  'HGB_div_LY',
#  'HGB_div_LYBL%',
#  'HGB_div_MCH',
#  'HGB_div_MCHC',
#  'HGB_div_MCV',
#  'HGB_div_MONO',
#  'HGB_div_MONO%',
#  'HGB_div_MPV',
#  'HGB_div_NEUT',
#  'HGB_div_NEUT%',
#  'HGB_div_NRBC#',
#  'HGB_div_NRBC%',
#  'HGB_div_P-LCR',
#  'HGB_div_PCT',
#  'HGB_div_PDW',
#  'HGB_div_PLT',
#  'HGB_div_RDW-CV',
#  'HGB_div_RDW-SD',
#  'IG#',
#  'IG#_div_CRP',
#  'IG#_div_HFLC1',
#  'IG#_div_HFLC2',
#  'IG#_div_NRBC#',
#  'IG#_div_NRBC%',
#  'IG%_div_HFLC1',
#  'IG%_div_NRBC#',
#  'LY',
#  'LYBL%',
#  'LYBL%_div_BASO%',
#  'LYBL%_div_CRP',
#  'LYBL%_div_EO%',
#  'LYBL%_div_HFLC1',
#  'LYBL%_div_HFLC2',
#  'LYBL%_div_IG#',
#  'LYBL%_div_IG%',
#  'LYBL%_div_NRBC#',
#  'LYBL%_div_NRBC%',
#  'LY_div_BASO',
#  'LY_div_BASO%',
#  'LY_div_CRP',
#  'LY_div_EO',
#  'LY_div_EO%',
#  'LY_div_HFLC1',
#  'LY_div_HFLC2',
#  'LY_div_IG#',
#  'LY_div_IG%',
#  'LY_div_LYBL%',
#  'LY_div_MONO',
#  'LY_div_MONO%',
#  'LY_div_NRBC#',
#  'LY_div_NRBC%',
#  'MCH',
#  'MCHC',
#  'MCHC_div_BASO',
#  'MCHC_div_BASO%',
#  'MCHC_div_CRP',
#  'MCHC_div_EO',
#  'MCHC_div_EO%',
#  'MCHC_div_HFLC1',
#  'MCHC_div_HFLC2',
#  'MCHC_div_IG#',
#  'MCHC_div_IG%',
#  'MCHC_div_LY',
#  'MCHC_div_LYBL%',
#  'MCHC_div_MONO',
#  'MCHC_div_MONO%',
#  'MCHC_div_MPV',
#  'MCHC_div_NEUT',
#  'MCHC_div_NEUT%',
#  'MCHC_div_NRBC#',
#  'MCHC_div_NRBC%',
#  'MCHC_div_P-LCR',
#  'MCHC_div_PCT',
#  'MCHC_div_PDW',
#  'MCHC_div_PLT',
#  'MCHC_div_RDW-SD',
#  'MCH_div_BASO',
#  'MCH_div_BASO%',
#  'MCH_div_CRP',
#  'MCH_div_EO',
#  'MCH_div_EO%',
#  'MCH_div_HFLC1',
#  'MCH_div_HFLC2',
#  'MCH_div_IG#',
#  'MCH_div_IG%',
#  'MCH_div_LY',
#  'MCH_div_LYBL%',
#  'MCH_div_MCHC',
#  'MCH_div_MONO',
#  'MCH_div_MONO%',
#  'MCH_div_MPV',
#  'MCH_div_NEUT',
#  'MCH_div_NEUT%',
#  'MCH_div_NRBC#',
#  'MCH_div_NRBC%',
#  'MCH_div_P-LCR',
#  'MCH_div_PCT',
#  'MCH_div_PDW',
#  'MCH_div_PLT',
#  'MCH_div_RDW-CV',
#  'MCH_div_RDW-SD',
#  'MCV',
#  'MCV_div_BASO',
#  'MCV_div_BASO%',
#  'MCV_div_CRP',
#  'MCV_div_EO',
#  'MCV_div_EO%',
#  'MCV_div_HFLC1',
#  'MCV_div_HFLC2',
#  'MCV_div_IG#',
#  'MCV_div_IG%',
#  'MCV_div_LY',
#  'MCV_div_LYBL%',
#  'MCV_div_MCHC',
#  'MCV_div_MONO',
#  'MCV_div_MONO%',
#  'MCV_div_MPV',
#  'MCV_div_NEUT',
#  'MCV_div_NEUT%',
#  'MCV_div_NRBC#',
#  'MCV_div_NRBC%',
#  'MCV_div_P-LCR',
#  'MCV_div_PCT',
#  'MCV_div_PDW',
#  'MCV_div_PLT',
#  'MCV_div_RDW-CV',
#  'MCV_div_RDW-SD',
#  'MONO',
#  'MONO%_div_CRP',
#  'MONO%_div_HFLC1',
#  'MONO%_div_HFLC2',
#  'MONO%_div_IG#',
#  'MONO%_div_IG%',
#  'MONO%_div_NRBC#',
#  'MONO%_div_NRBC%',
#  'MONO_div_BASO',
#  'MONO_div_CRP',
#  'MONO_div_EO',
#  'MONO_div_EO%',
#  'MONO_div_HFLC1',
#  'MONO_div_HFLC2',
#  'MONO_div_IG#',
#  'MONO_div_IG%',
#  'MONO_div_NEUT%',
#  'MONO_div_NRBC#',
#  'MONO_div_NRBC%',
#  'MPV',
#  'MPV_div_BASO',
#  'MPV_div_BASO%',
#  'MPV_div_CRP',
#  'MPV_div_EO',
#  'MPV_div_EO%',
#  'MPV_div_HFLC1',
#  'MPV_div_HFLC2',
#  'MPV_div_IG#',
#  'MPV_div_IG%',
#  'MPV_div_LY',
#  'MPV_div_LYBL%',
#  'MPV_div_MONO',
#  'MPV_div_MONO%',
#  'MPV_div_NEUT',
#  'MPV_div_NEUT%',
#  'MPV_div_NRBC#',
#  'MPV_div_NRBC%',
#  'MPV_div_PCT',
#  'NEUT',
#  'NEUT%',
#  'NEUT%_div_BASO%',
#  'NEUT%_div_CRP',
#  'NEUT%_div_EO%',
#  'NEUT%_div_HFLC1',
#  'NEUT%_div_HFLC2',
#  'NEUT%_div_IG#',
#  'NEUT%_div_IG%',
#  'NEUT%_div_MONO%',
#  'NEUT%_div_NRBC#',
#  'NEUT%_div_NRBC%',
#  'NEUT_div_BASO',
#  'NEUT_div_BASO%',
#  'NEUT_div_CRP',
#  'NEUT_div_EO',
#  'NEUT_div_EO%',
#  'NEUT_div_HFLC1',
#  'NEUT_div_HFLC2',
#  'NEUT_div_IG#',
#  'NEUT_div_IG%',
#  'NEUT_div_LY',
#  'NEUT_div_LYBL%',
#  'NEUT_div_MONO',
#  'NEUT_div_MONO%',
#  'NEUT_div_NEUT%',
#  'NEUT_div_NRBC#',
#  'NEUT_div_NRBC%',
#  'P-LCR',
#  'P-LCR_div_BASO',
#  'P-LCR_div_BASO%',
#  'P-LCR_div_CRP',
#  'P-LCR_div_EO',
#  'P-LCR_div_EO%',
#  'P-LCR_div_HFLC1',
#  'P-LCR_div_HFLC2',
#  'P-LCR_div_IG#',
#  'P-LCR_div_IG%',
#  'P-LCR_div_LY',
#  'P-LCR_div_LYBL%',
#  'P-LCR_div_MONO',
#  'P-LCR_div_MONO%',
#  'P-LCR_div_NEUT',
#  'P-LCR_div_NRBC#',
#  'P-LCR_div_NRBC%',
#  'PCT',
#  'PCT_div_BASO',
#  'PCT_div_BASO%',
#  'PCT_div_CRP',
#  'PCT_div_EO',
#  'PCT_div_EO%',
#  'PCT_div_HFLC1',
#  'PCT_div_HFLC2',
#  'PCT_div_IG#',
#  'PCT_div_IG%',
#  'PCT_div_LY',
#  'PCT_div_LYBL%',
#  'PCT_div_MONO',
#  'PCT_div_MONO%',
#  'PCT_div_NEUT%',
#  'PCT_div_NRBC#',
#  'PCT_div_NRBC%',
#  'PDW',
#  'PDW_div_BASO',
#  'PDW_div_BASO%',
#  'PDW_div_CRP',
#  'PDW_div_EO',
#  'PDW_div_EO%',
#  'PDW_div_HFLC1',
#  'PDW_div_HFLC2',
#  'PDW_div_IG#',
#  'PDW_div_IG%',
#  'PDW_div_LY',
#  'PDW_div_LYBL%',
#  'PDW_div_MONO',
#  'PDW_div_MONO%',
#  'PDW_div_MPV',
#  'PDW_div_NEUT',
#  'PDW_div_NEUT%',
#  'PDW_div_NRBC#',
#  'PDW_div_NRBC%',
#  'PDW_div_P-LCR',
#  'PDW_div_PCT',
#  'PLT',
#  'PLT_div_BASO',
#  'PLT_div_BASO%',
#  'PLT_div_CRP',
#  'PLT_div_EO',
#  'PLT_div_EO%',
#  'PLT_div_HFLC1',
#  'PLT_div_HFLC2',
#  'PLT_div_IG#',
#  'PLT_div_IG%',
#  'PLT_div_LY',
#  'PLT_div_LYBL%',
#  'PLT_div_MONO',
#  'PLT_div_MONO%',
#  'PLT_div_MPV',
#  'PLT_div_NEUT',
#  'PLT_div_NRBC#',
#  'PLT_div_NRBC%',
#  'PLT_div_P-LCR',
#  'PLT_div_PCT',
#  'PLT_div_PDW',
#  'PLT_div_RDW-SD',
#  'PtAge_div_BASO',
#  'PtAge_div_BASO%',
#  'PtAge_div_CRP',
#  'PtAge_div_EO',
#  'PtAge_div_EO%',
#  'PtAge_div_HCT',
#  'PtAge_div_HFLC1',
#  'PtAge_div_HFLC2',
#  'PtAge_div_HGB',
#  'PtAge_div_IG#',
#  'PtAge_div_IG%',
#  'PtAge_div_LY',
#  'PtAge_div_LYBL%',
#  'PtAge_div_MCH',
#  'PtAge_div_MCHC',
#  'PtAge_div_MCV',
#  'PtAge_div_MONO',
#  'PtAge_div_MONO%',
#  'PtAge_div_MPV',
#  'PtAge_div_NEUT',
#  'PtAge_div_NEUT%',
#  'PtAge_div_NRBC#',
#  'PtAge_div_P-LCR',
#  'PtAge_div_PCT',
#  'PtAge_div_PDW',
#  'PtAge_div_PLT',
#  'PtAge_div_RBC',
#  'PtAge_div_RDW-CV',
#  'PtAge_div_RDW-SD',
#  'PtAge_div_WBC',
#  'RBC',
#  'RBC_div_BASO',
#  'RBC_div_BASO%',
#  'RBC_div_CRP',
#  'RBC_div_EO',
#  'RBC_div_EO%',
#  'RBC_div_HCT',
#  'RBC_div_HFLC1',
#  'RBC_div_HFLC2',
#  'RBC_div_HGB',
#  'RBC_div_IG#',
#  'RBC_div_IG%',
#  'RBC_div_LY',
#  'RBC_div_LYBL%',
#  'RBC_div_MCH',
#  'RBC_div_MCHC',
#  'RBC_div_MCV',
#  'RBC_div_MONO',
#  'RBC_div_MONO%',
#  'RBC_div_MPV',
#  'RBC_div_NEUT',
#  'RBC_div_NEUT%',
#  'RBC_div_NRBC#',
#  'RBC_div_NRBC%',
#  'RBC_div_P-LCR',
#  'RBC_div_PCT',
#  'RBC_div_PDW',
#  'RBC_div_PLT',
#  'RBC_div_RDW-CV',
#  'RBC_div_RDW-SD',
#  'RDW-CV',
#  'RDW-CV_div_BASO',
#  'RDW-CV_div_BASO%',
#  'RDW-CV_div_CRP',
#  'RDW-CV_div_EO',
#  'RDW-CV_div_EO%',
#  'RDW-CV_div_HFLC1',
#  'RDW-CV_div_HFLC2',
#  'RDW-CV_div_IG#',
#  'RDW-CV_div_IG%',
#  'RDW-CV_div_LY',
#  'RDW-CV_div_LYBL%',
#  'RDW-CV_div_MONO',
#  'RDW-CV_div_MONO%',
#  'RDW-CV_div_MPV',
#  'RDW-CV_div_NEUT',
#  'RDW-CV_div_NEUT%',
#  'RDW-CV_div_NRBC#',
#  'RDW-CV_div_NRBC%',
#  'RDW-CV_div_P-LCR',
#  'RDW-CV_div_PDW',
#  'RDW-SD',
#  'RDW-SD_div_BASO',
#  'RDW-SD_div_BASO%',
#  'RDW-SD_div_CRP',
#  'RDW-SD_div_EO',
#  'RDW-SD_div_EO%',
#  'RDW-SD_div_HFLC1',
#  'RDW-SD_div_HFLC2',
#  'RDW-SD_div_IG#',
#  'RDW-SD_div_IG%',
#  'RDW-SD_div_LY',
#  'RDW-SD_div_LYBL%',
#  'RDW-SD_div_MONO',
#  'RDW-SD_div_MONO%',
#  'RDW-SD_div_MPV',
#  'RDW-SD_div_NEUT',
#  'RDW-SD_div_NEUT%',
#  'RDW-SD_div_NRBC#',
#  'RDW-SD_div_NRBC%',
#  'RDW-SD_div_P-LCR',
#  'RDW-SD_div_PCT',
#  'RDW-SD_div_PDW',
#  'WBC',
#  'WBC_div_BASO',
#  'WBC_div_BASO%',
#  'WBC_div_CRP',
#  'WBC_div_EO',
#  'WBC_div_EO%',
#  'WBC_div_HCT',
#  'WBC_div_HFLC1',
#  'WBC_div_HFLC2',
#  'WBC_div_HGB',
#  'WBC_div_IG#',
#  'WBC_div_IG%',
#  'WBC_div_LY',
#  'WBC_div_LYBL%',
#  'WBC_div_MCH',
#  'WBC_div_MCHC',
#  'WBC_div_MCV',
#  'WBC_div_MONO',
#  'WBC_div_MONO%',
#  'WBC_div_MPV',
#  'WBC_div_NEUT',
#  'WBC_div_NEUT%',
#  'WBC_div_NRBC#',
#  'WBC_div_NRBC%',
#  'WBC_div_P-LCR',
#  'WBC_div_PCT',
#  'WBC_div_PDW',
#  'WBC_div_PLT',
#  'WBC_div_RBC',
#  'WBC_div_RDW-CV',
#  'WBC_div_RDW-SD'}

# %% [markdown]
# ### 用决策树来做数据分箱

# %%
for i in range(len(X_bin.columns)):
    print(X_bin.columns[i])
    boundary = optimal_binning_boundary(X_bin.iloc[:,i], y)
    print(boundary)
    
    X_bin.iloc[:,i] = pd.cut(X_bin.iloc[:,i], bins=boundary, labels=False, include_lowest=True)
    print(X_bin.iloc[:,i].value_counts())
    print('-----------------------')
# Out:
# PtAge
# [-inf, 0.3333333333333333, 13.5, 97.1, inf]
# PtAge
# 2.0    6846
# 1.0    1124
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# WBC
# [-inf, 1e-08, 8.444999694824219, 11.045000076293945, 50.89, inf]
# WBC
# 1.0    5466
# 2.0    1534
# 3.0     955
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# RBC
# [-inf, 1e-08, 3.9350000619888306, 7.449999999999999, inf]
# RBC
# 2.0    7521
# 1.0     442
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# HGB
# [-inf, 1e-08, 141.5, 148.5, 203.1, inf]
# HGB
# 1.0    4695
# 3.0    2206
# 2.0    1066
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# HCT
# [-inf, 1e-08, 42.25, 43.64999961853027, 61.6, inf]
# HCT
# 1.0    4688
# 3.0    2451
# 2.0     826
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# MCV
# [-inf, 1e-08, 87.14999771118164, 90.14999771118164, 129.29999999999998, inf]
# MCV
# 3.0    3254
# 1.0    2499
# 2.0    2206
# 0.0      12
# Name: count, dtype: int64
# -----------------------
# MCH
# [-inf, 1e-08, 28.949999809265137, 29.550000190734863, 39.5, inf]
# MCH
# 3.0    4716
# 1.0    2310
# 2.0     929
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# MCHC
# [-inf, 1e-08, 322.5, 332.5, 410.1, inf]
# MCHC
# 3.0    4997
# 2.0    2225
# 1.0     741
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# PLT
# [-inf, 1e-08, 282.5, 286.5, 726.1, inf]
# PLT
# 1.0    6428
# 3.0    1410
# 2.0     119
# 0.0      14
# Name: count, dtype: int64
# -----------------------
# RDW-SD
# [-inf, 1e-08, 42.64999961853027, 46.95000076293945, 197.29999999999998, inf]
# RDW-SD
# 1.0    5199
# 2.0    2346
# 3.0     401
# 0.0      25
# Name: count, dtype: int64
# -----------------------
# RDW-CV
# [-inf, 1e-08, 12.050000190734863, 12.150000095367432, 46.800000000000004, inf]
# RDW-CV
# 3.0    6341
# 1.0    1329
# 2.0     267
# 0.0      34
# Name: count, dtype: int64
# -----------------------
# PDW
# [-inf, 1e-08, 14.650000095367432, 14.949999809265137, 22.200000000000003, inf]
# PDW
# 3.0    5277
# 1.0    2664
# 0.0      23
# 2.0       7
# Name: count, dtype: int64
# -----------------------
# MPV
# [-inf, 1e-08, 8.349999904632568, 8.650000095367432, 14.6, inf]
# MPV
# 3.0    6277
# 1.0    1007
# 2.0     664
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# P-LCR
# [-inf, 1e-08, 14.75, 15.75, 64.19999999999999, inf]
# P-LCR
# 3.0    6462
# 1.0    1092
# 2.0     389
# 0.0      28
# Name: count, dtype: int64
# -----------------------
# PCT
# [-inf, 1e-08, 0.23149999976158142, 0.25049999356269836, 0.739, inf]
# PCT
# 1.0    5203
# 3.0    1796
# 2.0     945
# 0.0      27
# Name: count, dtype: int64
# -----------------------
# NEUT
# [-inf, 1e-08, 2.1049998998641968, 9.324999809265137, 28.68, inf]
# NEUT
# 2.0    6825
# 3.0     673
# 1.0     451
# 0.0      22
# Name: count, dtype: int64
# -----------------------
# LY
# [-inf, 1e-08, 1.5750000476837158, 2.2450000047683716, 13.889999999999999, inf]
# LY
# 1.0    5375
# 2.0    1444
# 3.0    1123
# 0.0      29
# Name: count, dtype: int64
# -----------------------
# MONO
# [-inf, 1e-08, 0.574999988079071, 0.6050000190734863, 27.380000000000003, inf]
# MONO
# 3.0    4494
# 1.0    3095
# 2.0     374
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# EO
# [-inf, 1e-08, 0.10500000044703484, 0.16499999910593033, 1.85, inf]
# EO
# 1.0    5087
# 0.0    1250
# 3.0     914
# 2.0     720
# Name: count, dtype: int64
# -----------------------
# BASO
# [-inf, 1e-08, 0.005000004888241261, 0.26, inf]
# BASO
# 2.0    6773
# 0.0    1198
# Name: count, dtype: int64
# -----------------------
# NEUT%
# [-inf, 1e-08, 60.45000076293945, 62.45000076293945, 96.0, inf]
# NEUT%
# 3.0    5814
# 1.0    1781
# 2.0     372
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# LYBL%
# [-inf, 1e-08, 26.550000190734863, 26.65000057220459, 85.89999999999999, inf]
# LYBL%
# 1.0    6085
# 3.0    1852
# 2.0      24
# 0.0      10
# Name: count, dtype: int64
# -----------------------
# MONO%
# [-inf, 1e-08, 8.550000190734863, 8.75, 53.800000000000004, inf]
# MONO%
# 3.0    4300
# 1.0    3510
# 2.0     153
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# EO%
# [-inf, 1e-08, 0.8499999940395355, 1.75, 14.7, inf]
# EO%
# 1.0    4202
# 2.0    1374
# 3.0    1278
# 0.0    1117
# Name: count, dtype: int64
# -----------------------
# BASO%
# [-inf, 1e-08, 0.15000000223517418, 4.0, inf]
# BASO%
# 2.0    4943
# 1.0    2020
# 0.0    1008
# Name: count, dtype: int64
# -----------------------
# IG#
# [-inf, 1e-08, 0.005000004888241261, 0.024999999441206455, 5.369999999999999, inf]
# IG#
# 2.0    4727
# 3.0    1701
# 0.0    1543
# Name: count, dtype: int64
# -----------------------
# IG%
# [-inf, 1e-08, 0.15000000223517418, 21.6, inf]
# IG%
# 2.0    4418
# 1.0    2322
# 0.0    1231
# Name: count, dtype: int64
# -----------------------
# CRP
# [-inf, 1e-08, 2.84499990940094, 3.7050000429153442, 287.64000000000004, inf]
# CRP
# 3.0    6170
# 1.0    1284
# 2.0     336
# 0.0     181
# Name: count, dtype: int64
# -----------------------
# HFLC1
# [-inf, 1e-08, 0.025377808138728142, 1.5, inf]
# HFLC1
# 1.0    4347
# 0.0    2010
# 2.0    1614
# Name: count, dtype: int64
# -----------------------
# HFLC2
# [-inf, 1e-08, 0.45000000298023224, 15.7, inf]
# HFLC2
# 1.0    5049
# 0.0    1702
# 2.0    1220
# Name: count, dtype: int64
# -----------------------
# NRBC#
# [-inf, 1e-08, 0.00016864404602356942, 0.334, inf]
# NRBC#
# 0.0    5218
# 2.0    2753
# Name: count, dtype: int64
# -----------------------
# NRBC%
# [-inf, 1e-08, 0.0017780160938474232, 2.27, inf]
# NRBC%
# 0.0    5223
# 2.0    2748
# Name: count, dtype: int64
# -----------------------
# PtAge_div_WBC
# [-inf, 0.04510599909788, 1.27324640750885, 1.7788411974906921, 2800000000.1, inf]
# PtAge_div_WBC
# 3.0    6403
# 1.0     969
# 2.0     595
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_RBC
# [-inf, 0.0754147812971342, 2.4799795150756836, 2.6150366067886353, 2800000000.1, inf]
# PtAge_div_RBC
# 3.0    6888
# 1.0     998
# 2.0      81
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_HGB
# [-inf, 0.0025252525252525, 0.08740079402923584, 0.08802515640854836, 2800000000.1, inf]
# PtAge_div_HGB
# 3.0    6920
# 1.0    1036
# 2.0      11
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_HCT
# [-inf, 0.0089126559714795, 0.2925402820110321, 0.29815685749053955, 2800000000.1, inf]
# PtAge_div_HCT
# 3.0    6885
# 1.0    1053
# 2.0      29
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MCV
# [-inf, 0.003935458480913, 0.14916814863681793, 0.15066849440336227, 2800000000.1, inf]
# PtAge_div_MCV
# 3.0    6844
# 1.0    1109
# 2.0      14
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MCH
# [-inf, 0.0111482720178372, 0.44849690794944763, 0.4552857577800751, 2800000000.1, inf]
# PtAge_div_MCH
# 3.0    6816
# 1.0    1110
# 2.0      41
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MCHC
# [-inf, 0.0009442870632672, 0.04029675014317036, 0.040359245613217354, 2800000000.1, inf]
# PtAge_div_MCHC
# 3.0    6841
# 1.0    1124
# 0.0       4
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# PtAge_div_PLT
# [-inf, 0.0012626262626262, 0.04818574897944927, 0.053306011483073235, 2800000000.1, inf]
# PtAge_div_PLT
# 3.0    6681
# 1.0    1118
# 2.0     168
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_RDW-SD
# [-inf, 0.0085689802913453, 0.30751046538352966, 0.3186889737844467, 2800000000.1, inf]
# PtAge_div_RDW-SD
# 3.0    6809
# 1.0    1089
# 2.0      69
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_RDW-CV
# [-inf, 0.02710027100271, 0.9668254852294922, 1.040833294391632, 2800000000.1, inf]
# PtAge_div_RDW-CV
# 3.0    6748
# 1.0    1091
# 2.0     128
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_PDW
# [-inf, 0.0213675213675213, 0.8254051208496094, 0.8410415649414062, 3800000000.1, inf]
# PtAge_div_PDW
# 3.0    6812
# 1.0    1114
# 0.0      24
# 2.0      21
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MPV
# [-inf, 0.03584229390681, 1.255630612373352, 1.3269820809364319, 3800000000.1, inf]
# PtAge_div_MPV
# 3.0    6878
# 1.0     979
# 2.0      90
# 0.0      24
# Name: count, dtype: int64
# -----------------------
# PtAge_div_P-LCR
# [-inf, 0.0165016501650165, 0.4075080454349518, 0.5904785394668579, 3800000000.1, inf]
# PtAge_div_P-LCR
# 3.0    6646
# 2.0     692
# 1.0     609
# 0.0      24
# Name: count, dtype: int64
# -----------------------
# PtAge_div_PCT
# [-inf, 1.3354700854700856, 51.579647064208984, 55.453054428100586, 3800000000.1, inf]
# PtAge_div_PCT
# 3.0    6727
# 1.0    1084
# 2.0     136
# 0.0      24
# Name: count, dtype: int64
# -----------------------
# PtAge_div_NEUT
# [-inf, 0.0719631548647092, 2.198607921600342, 2.4951186180114746, 2800000000.1, inf]
# PtAge_div_NEUT
# 3.0    6450
# 1.0    1268
# 2.0     249
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_LY
# [-inf, 0.0728256346233874, 6.633862257003784, 7.288217306137085, 2800000000.1, inf]
# PtAge_div_LY
# 3.0    6738
# 1.0    1114
# 2.0     115
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MONO
# [-inf, 0.5401234567901234, 12.254524230957031, 17.340136528015137, 6900000000.1, inf]
# PtAge_div_MONO
# 3.0    6681
# 1.0     653
# 2.0     632
# 0.0       5
# Name: count, dtype: int64
# -----------------------
# PtAge_div_EO
# [-inf, 0.9950248756218903, 101.42856979370117, 206.06617736816406, 9400000000.1, inf]
# PtAge_div_EO
# 3.0    6187
# 1.0     943
# 2.0     761
# 0.0      80
# Name: count, dtype: int64
# -----------------------
# PtAge_div_BASO
# [-inf, 33.33333333333333, 9000.0, 20838034.0, 9700000000.1, inf]
# PtAge_div_BASO
# 1.0    6777
# 3.0    1099
# 0.0      93
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# PtAge_div_NEUT%
# [-inf, 0.0055928411633109, 0.16564278304576874, 0.1975984200835228, 2800000000.1, inf]
# PtAge_div_NEUT%
# 3.0    6719
# 1.0     821
# 2.0     427
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_LYBL%
# [-inf, 0.005050505050505, 0.44477415084838867, 0.5473544597625732, 2800000000.1, inf]
# PtAge_div_LYBL%
# 3.0    6671
# 1.0    1020
# 2.0     276
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# PtAge_div_MONO%
# [-inf, 0.0305810397553516, 0.7532285153865814, 1.0383484363555908, 6900000000.1, inf]
# PtAge_div_MONO%
# 3.0    7177
# 1.0     395
# 2.0     394
# 0.0       5
# Name: count, dtype: int64
# -----------------------
# PtAge_div_EO%
# [-inf, 0.1176470588235294, 8.02439022064209, 20.7417573928833, 9400000000.1, inf]
# PtAge_div_EO%
# 3.0    5712
# 2.0    1214
# 1.0     958
# 0.0      87
# Name: count, dtype: int64
# -----------------------
# PtAge_div_BASO%
# [-inf, 3.333333333333333, 915.0, 20833804.0, 9700000000.1, inf]
# PtAge_div_BASO%
# 1.0    6969
# 3.0     915
# 0.0      86
# 2.0       1
# Name: count, dtype: int64
# -----------------------
# PtAge_div_IG#
# [-inf, 6.666666666666666, 705.0, 1336.6666870117188, 8900000000.1, inf]
# PtAge_div_IG#
# 3.0    5154
# 1.0    1455
# 2.0    1309
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# PtAge_div_IG%
# [-inf, 0.7638888888888888, 41.5476188659668, 71.0, 8900000000.1, inf]
# PtAge_div_IG%
# 3.0    6082
# 2.0    1020
# 1.0     810
# 0.0      59
# Name: count, dtype: int64
# -----------------------
# PtAge_div_CRP
# [-inf, 0.0132135306553911, 0.4578108489513397, 7.453980922698975, 7300000000.1, inf]
# PtAge_div_CRP
# 2.0    6005
# 3.0    1316
# 1.0     550
# 0.0     100
# Name: count, dtype: int64
# -----------------------
# PtAge_div_HFLC1
# [-inf, 1.4957264957264955, 353.57142639160156, 436.6666717529297, 8900000000.1, inf]
# PtAge_div_HFLC1
# 3.0    6815
# 1.0    1026
# 2.0     120
# 0.0      10
# Name: count, dtype: int64
# -----------------------
# PtAge_div_HFLC2
# [-inf, 0.125, 36.77083396911621, 8900000000.1, inf]
# PtAge_div_HFLC2
# 2.0    6660
# 1.0    1294
# 0.0      17
# Name: count, dtype: int64
# -----------------------
# PtAge_div_NRBC#
# [-inf, 253.84615384615384, 203096.4921875, 2050000000.0, 9500000000.1, inf]
# PtAge_div_NRBC#
# 3.0    2942
# 1.0    2716
# 2.0    2312
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# PtAge_div_NRBC%
# [-inf, 16.176470588235293, 19263.0966796875, 2050000000.0, 9500000000.1, inf]
# PtAge_div_NRBC%
# 3.0    2942
# 1.0    2716
# 2.0    2312
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# WBC_div_RBC
# [-inf, 0.0866807610993657, 1.7652678489685059, 2.2656538486480713, 18.70439560439561, inf]
# WBC_div_RBC
# 1.0    5336
# 2.0    1422
# 3.0    1192
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# WBC_div_HGB
# [-inf, 0.0029496402877697, 0.0656350776553154, 0.0682421401143074, 1.1, inf]
# WBC_div_HGB
# 1.0    5953
# 3.0    1784
# 2.0     218
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# WBC_div_HCT
# [-inf, 0.0101485148514851, 0.19829469919204712, 0.22200217843055725, 2.0166037735849054, inf]
# WBC_div_HCT
# 1.0    5252
# 3.0    1911
# 2.0     788
# 0.0      20
# Name: count, dtype: int64
# -----------------------
# WBC_div_MCV
# [-inf, 0.0047953216374269, 0.09555434435606003, 0.10399530455470085, 1.1, inf]
# WBC_div_MCV
# 1.0    5460
# 3.0    1926
# 2.0     569
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# WBC_div_MCH
# [-inf, 0.0139931740614334, 0.28239215910434723, 0.2895347625017166, 1.6532110091743122, inf]
# WBC_div_MCH
# 1.0    5376
# 3.0    2409
# 2.0     168
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# WBC_div_MCHC
# [-inf, 0.0011918604651162, 0.02677413448691368, 0.02729810494929552, 1.1, inf]
# WBC_div_MCHC
# 1.0    5880
# 3.0    1962
# 2.0     124
# 0.0       5
# Name: count, dtype: int64
# -----------------------
# WBC_div_PLT
# [-inf, 0.0022282608695652, 0.025019878521561623, 0.04763130657374859, 1.99, inf]
# WBC_div_PLT
# 2.0    4955
# 1.0    1995
# 3.0    1007
# 0.0      14
# Name: count, dtype: int64
# -----------------------
# WBC_div_RDW-SD
# [-inf, 0.009297052154195, 0.21862223744392395, 0.2199040725827217, 1.1, inf]
# WBC_div_RDW-SD
# 1.0    5989
# 3.0    1934
# 2.0      32
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# WBC_div_RDW-CV
# [-inf, 0.0290780141843971, 0.7237349152565002, 0.7437728047370911, 3.486, inf]
# WBC_div_RDW-CV
# 1.0    6129
# 3.0    1637
# 2.0     193
# 0.0      12
# Name: count, dtype: int64
# -----------------------
# WBC_div_PDW
# [-inf, 0.0253086419753086, 0.7649227380752563, 0.927812933921814, 1382000000.1, inf]
# WBC_div_PDW
# 1.0    6578
# 2.0     719
# 3.0     653
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# WBC_div_MPV
# [-inf, 0.0546666666666666, 1.0190743803977966, 1.158190667629242, 1382000000.1, inf]
# WBC_div_MPV
# 1.0    6183
# 3.0    1154
# 2.0     613
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# WBC_div_P-LCR
# [-inf, 0.0336065573770491, 0.5208738744258881, 0.6091045439243317, 1382000000.1, inf]
# WBC_div_P-LCR
# 1.0    6304
# 3.0    1076
# 2.0     570
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# WBC_div_PCT
# [-inf, 1.0, 28.878676414489746, 47.31818199157715, 1382000000.1, inf]
# WBC_div_PCT
# 2.0    3978
# 1.0    2663
# 3.0    1307
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# WBC_div_NEUT
# [-inf, 1.0, 1.627095341682434, 1.6544229984283447, 41.5, inf]
# WBC_div_NEUT
# 1.0    5997
# 3.0    1772
# 2.0     186
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# WBC_div_LY
# [-inf, 1.0, 3.7386927604675293, 3.7422252893447876, 77.87777777777778, inf]
# WBC_div_LY
# 3.0    6094
# 1.0    1841
# 0.0      33
# 2.0       3
# Name: count, dtype: int64
# -----------------------
# WBC_div_MONO
# [-inf, 1.0, 10.629159450531006, 11.438261985778809, 259000000.1, inf]
# WBC_div_MONO
# 1.0    3734
# 3.0    3653
# 2.0     580
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# WBC_div_EO
# [-inf, 1.0, 78.29166793823242, 129.20833587646484, 5079000000.1, inf]
# WBC_div_EO
# 3.0    5042
# 1.0    1878
# 2.0    1010
# 0.0      41
# Name: count, dtype: int64
# -----------------------
# WBC_div_BASO
# [-inf, 1.0, 790.25, 797.75, 5079000000.1, inf]
# WBC_div_BASO
# 1.0    5850
# 3.0    2056
# 0.0      38
# 2.0      27
# Name: count, dtype: int64
# -----------------------
# WBC_div_NEUT%
# [-inf, 0.0166666666666666, 0.14222335070371628, 0.14463575929403305, 5.2749999999999995, inf]
# WBC_div_NEUT%
# 1.0    6441
# 3.0    1416
# 2.0     101
# 0.0      13
# Name: count, dtype: int64
# -----------------------
# WBC_div_LYBL%
# [-inf, 0.0073873873873873, 0.17574158310890198, 0.33439619839191437, 21.638461538461538, inf]
# WBC_div_LYBL%
# 3.0    4686
# 2.0    2159
# 1.0    1084
# 0.0      42
# Name: count, dtype: int64
# -----------------------
# WBC_div_MONO%
# [-inf, 0.023728813559322, 1.1836077570915222, 1.1840561032295227, 259000000.1, inf]
# WBC_div_MONO%
# 1.0    5774
# 3.0    2192
# 2.0       3
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# WBC_div_EO%
# [-inf, 0.0719298245614035, 4.7324559688568115, 7.920833349227905, 5079000000.1, inf]
# WBC_div_EO%
# 3.0    5315
# 1.0    1657
# 2.0     957
# 0.0      42
# Name: count, dtype: int64
# -----------------------
# WBC_div_BASO%
# [-inf, 0.1051282051282051, 38.158334732055664, 86.85000228881836, 5079000000.1, inf]
# WBC_div_BASO%
# 1.0    4169
# 2.0    2009
# 3.0    1755
# 0.0      38
# Name: count, dtype: int64
# -----------------------
# WBC_div_IG#
# [-inf, 1.0, 855.5, 608500000.0, 2180000000.1, inf]
# WBC_div_IG#
# 1.0    5804
# 2.0    1710
# 3.0     424
# 0.0      33
# Name: count, dtype: int64
# -----------------------
# WBC_div_IG%
# [-inf, 0.0944186046511627, 32.97500038146973, 44.47500038146973, 2180000000.1, inf]
# WBC_div_IG%
# 3.0    3968
# 1.0    3132
# 2.0     835
# 0.0      36
# Name: count, dtype: int64
# -----------------------
# WBC_div_CRP
# [-inf, 0.0027657852131678, 2.000902533531189, 2.4710503816604614, 1694000000.1, inf]
# WBC_div_CRP
# 1.0    6291
# 3.0    1312
# 2.0     259
# 0.0     109
# Name: count, dtype: int64
# -----------------------
# WBC_div_HFLC1
# [-inf, 1.0, 220.875, 246.83333587646484, 2588000000.1, inf]
# WBC_div_HFLC1
# 3.0    6471
# 1.0    1278
# 2.0     208
# 0.0      14
# Name: count, dtype: int64
# -----------------------
# WBC_div_HFLC2
# [-inf, 0.0455555555555555, 18.41249942779541, 19.736666679382324, 3208000000.1, inf]
# WBC_div_HFLC2
# 3.0    6081
# 1.0    1739
# 2.0     129
# 0.0      22
# Name: count, dtype: int64
# -----------------------
# WBC_div_NRBC#
# [-inf, 2.9649122807017536e-05, 36201.578125, 44651.580078125, 3208000000.1, inf]
# WBC_div_NRBC#
# 3.0    5246
# 1.0    2635
# 2.0      84
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# WBC_div_NRBC%
# [-inf, 2.8121309715512613e-06, 3433.6119384765625, 4235.0693359375, 3208000000.1, inf]
# WBC_div_NRBC%
# 3.0    5246
# 1.0    2635
# 2.0      84
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# RBC_div_HGB
# [-inf, 0.0253968253968253, 0.03383287787437439, 0.03460061363875866, 1.1, inf]
# RBC_div_HGB
# 1.0    4693
# 3.0    2253
# 2.0    1021
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_HCT
# [-inf, 0.0773451327433628, 0.11156471818685532, 0.11475026980042458, 1.1, inf]
# RBC_div_HCT
# 1.0    3654
# 3.0    2508
# 2.0    1805
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_MCV
# [-inf, 0.0174147217235188, 0.04260721988976002, 0.04513656720519066, 1.1, inf]
# RBC_div_MCV
# 3.0    7006
# 2.0     489
# 1.0     472
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_MCH
# [-inf, 0.0510526315789473, 0.12484171614050865, 0.13741828501224518, 1.1, inf]
# RBC_div_MCH
# 3.0    6695
# 2.0     848
# 1.0     409
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# RBC_div_MCHC
# [-inf, 0.0051906158357771, 0.011568631045520306, 0.01214815629646182, 1.1, inf]
# RBC_div_MCHC
# 3.0    7154
# 2.0     412
# 1.0     401
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_PLT
# [-inf, 0.00431718061674, 0.017467470839619637, 0.018540048971772194, 1.1, inf]
# RBC_div_PLT
# 3.0    5232
# 1.0    2155
# 2.0     573
# 0.0      11
# Name: count, dtype: int64
# -----------------------
# RBC_div_RDW-SD
# [-inf, 0.0221602434077079, 0.08681835979223251, 0.08711904659867287, 1.1, inf]
# RBC_div_RDW-SD
# 3.0    7541
# 1.0     412
# 2.0      14
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_RDW-CV
# [-inf, 0.0935760171306209, 0.38936910033226013, 0.39026203751564026, 1.1, inf]
# RBC_div_RDW-CV
# 1.0    5550
# 3.0    2368
# 2.0      49
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# RBC_div_PDW
# [-inf, 0.1085889570552147, 0.3451710045337677, 0.36156393587589264, 698000000.1, inf]
# RBC_div_PDW
# 1.0    5246
# 3.0    2501
# 2.0     203
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# RBC_div_MPV
# [-inf, 0.1617021276595744, 0.5137434899806976, 0.5420753657817841, 698000000.1, inf]
# RBC_div_MPV
# 1.0    4731
# 3.0    2078
# 2.0    1141
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# RBC_div_P-LCR
# [-inf, 0.0404056162246489, 0.2613895833492279, 0.35660457611083984, 698000000.1, inf]
# RBC_div_P-LCR
# 1.0    5465
# 2.0    1903
# 3.0     582
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# RBC_div_PCT
# [-inf, 1.0, 19.41650390625, 20.77283763885498, 698000000.1, inf]
# RBC_div_PCT
# 3.0    4668
# 1.0    2504
# 2.0     776
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# RBC_div_NEUT
# [-inf, 0.1254789272030651, 0.6100854575634003, 2.2567524909973145, 59.22500000000001, inf]
# RBC_div_NEUT
# 2.0    6174
# 1.0    1382
# 3.0     399
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# RBC_div_LY
# [-inf, 0.231748726655348, 2.36981201171875, 2.6831700801849365, 37.28181818181818, inf]
# RBC_div_LY
# 3.0    5855
# 1.0    1552
# 2.0     540
# 0.0      24
# Name: count, dtype: int64
# -----------------------
# RBC_div_MONO
# [-inf, 0.1000733137829912, 8.533908367156982, 8.622796058654785, 448000000.1000001, inf]
# RBC_div_MONO
# 1.0    5353
# 3.0    2549
# 2.0      67
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# RBC_div_EO
# [-inf, 1.0, 34.86458396911621, 51.211111068725586, 735000000.1, inf]
# RBC_div_EO
# 3.0    6049
# 1.0    1276
# 2.0     643
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# RBC_div_BASO
# [-inf, 1.0, 388500000.0, 393000000.0, 632000000.1, inf]
# RBC_div_BASO
# 1.0    6844
# 3.0    1115
# 2.0       9
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# RBC_div_NEUT%
# [-inf, 0.020066889632107, 0.08068165928125381, 0.0842185728251934, 1.9083333333333332, inf]
# RBC_div_NEUT%
# 1.0    6265
# 3.0    1386
# 2.0     305
# 0.0      15
# Name: count, dtype: int64
# -----------------------
# RBC_div_LYBL%
# [-inf, 0.0515566625155666, 0.19153212010860443, 0.19197450578212738, 3.084615384615384, inf]
# RBC_div_LYBL%
# 3.0    5627
# 1.0    2310
# 0.0      28
# 2.0       6
# Name: count, dtype: int64
# -----------------------
# RBC_div_MONO%
# [-inf, 0.0503802281368821, 0.5760490000247955, 0.5819751024246216, 448000000.1000001, inf]
# RBC_div_MONO%
# 1.0    4945
# 3.0    2946
# 2.0      78
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# RBC_div_EO%
# [-inf, 0.2653061224489796, 3.390000104904175, 6.326785564422607, 735000000.1, inf]
# RBC_div_EO%
# 3.0    4980
# 1.0    1774
# 2.0    1216
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# RBC_div_BASO%
# [-inf, 1.0, 34.54999923706055, 42.25, 632000000.1, inf]
# RBC_div_BASO%
# 1.0    4982
# 3.0    2663
# 2.0     323
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# RBC_div_IG#
# [-inf, 0.4971537001897533, 225.75, 398500000.0, 735000000.1, inf]
# RBC_div_IG#
# 2.0    4366
# 1.0    2175
# 3.0    1429
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# RBC_div_IG%
# [-inf, 0.1055813953488372, 36.85000038146973, 39.30000114440918, 735000000.1, inf]
# RBC_div_IG%
# 1.0    4476
# 3.0    3432
# 2.0      62
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# RBC_div_CRP
# [-inf, 0.0107881083751955, 2.5879321098327637, 3.586503028869629, 590000000.1, inf]
# RBC_div_CRP
# 1.0    7029
# 3.0     578
# 2.0     236
# 0.0     128
# Name: count, dtype: int64
# -----------------------
# RBC_div_HFLC1
# [-inf, 1.0, 170.16666412353516, 183.58333587646484, 665000000.1, inf]
# RBC_div_HFLC1
# 3.0    6291
# 1.0    1599
# 2.0      78
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# RBC_div_HFLC2
# [-inf, 0.3019230769230769, 10.067500114440918, 10.677500247955322, 665000000.1, inf]
# RBC_div_HFLC2
# 3.0    6595
# 1.0    1274
# 2.0     101
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# RBC_div_NRBC#
# [-inf, 2.9649122807017536e-05, 368500000.0, 393500000.0, 718000000.1, inf]
# RBC_div_NRBC#
# 3.0    4869
# 1.0    2918
# 2.0     181
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# RBC_div_NRBC%
# [-inf, 2.8121309715512613e-06, 368500000.0, 393500000.0, 718000000.1, inf]
# RBC_div_NRBC%
# 3.0    4869
# 1.0    2918
# 2.0     181
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_HCT
# [-inf, 1.0, 3.222089648246765, 3.31791889667511, 4.204938271604938, inf]
# HGB_div_HCT
# 3.0    5158
# 2.0    2091
# 1.0     709
# 0.0      13
# Name: count, dtype: int64
# -----------------------
# HGB_div_MCV
# [-inf, 0.6018054162487462, 1.3033929467201233, 1.6883063316345215, 2.5547803617571057, inf]
# HGB_div_MCV
# 2.0    5637
# 3.0    1909
# 1.0     423
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# HGB_div_MCH
# [-inf, 1.0, 3.9310576915740967, 4.029040575027466, 7.435907335907336, inf]
# HGB_div_MCH
# 3.0    7305
# 1.0     445
# 2.0     213
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# HGB_div_MCHC
# [-inf, 0.1671732522796352, 0.42301882803440094, 0.43672792613506317, 1.1, inf]
# HGB_div_MCHC
# 1.0    4723
# 3.0    2433
# 2.0     809
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# HGB_div_PLT
# [-inf, 0.1294765840220385, 0.4981617331504822, 0.5780920386314392, 7.766666666666667, inf]
# HGB_div_PLT
# 3.0    4693
# 1.0    1939
# 2.0    1325
# 0.0      14
# Name: count, dtype: int64
# -----------------------
# HGB_div_RDW-SD
# [-inf, 0.720081135902637, 3.513222336769104, 3.5544395446777344, 5.521686746987951, inf]
# HGB_div_RDW-SD
# 1.0    5192
# 3.0    2550
# 2.0     228
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# HGB_div_RDW-CV
# [-inf, 1.0, 11.260173320770264, 11.498031616210938, 16.470967741935485, inf]
# HGB_div_RDW-CV
# 1.0    4704
# 3.0    2879
# 2.0     385
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_PDW
# [-inf, 1.0, 9.315248012542725, 10.806952476501465, 15100000000.1, inf]
# HGB_div_PDW
# 1.0    4162
# 3.0    2429
# 2.0    1357
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HGB_div_MPV
# [-inf, 1.0, 11.791749000549316, 12.246479988098145, 15100000000.1, inf]
# HGB_div_MPV
# 3.0    7020
# 1.0     636
# 2.0     292
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HGB_div_P-LCR
# [-inf, 1.0, 9.355781555175781, 10.132891654968262, 15100000000.1, inf]
# HGB_div_P-LCR
# 1.0    6826
# 3.0     743
# 2.0     379
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HGB_div_PCT
# [-inf, 1.0, 611.4460754394531, 611.9062194824219, 15100000000.1, inf]
# HGB_div_PCT
# 3.0    4768
# 1.0    3173
# 0.0      23
# 2.0       7
# Name: count, dtype: int64
# -----------------------
# HGB_div_NEUT
# [-inf, 1.0, 16.36265754699707, 18.90416145324707, 1737.6, inf]
# HGB_div_NEUT
# 3.0    6379
# 1.0    1025
# 2.0     549
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# HGB_div_LY
# [-inf, 1.0, 73.60564041137695, 85.11271667480469, 1136.4636363636364, inf]
# HGB_div_LY
# 3.0    5543
# 1.0    1747
# 2.0     655
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# HGB_div_MONO
# [-inf, 1.0, 233.8244857788086, 241.1239471435547, 11300000000.1, inf]
# HGB_div_MONO
# 1.0    4688
# 3.0    3003
# 2.0     276
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# HGB_div_EO
# [-inf, 1.0, 832.2916564941406, 1463.0681762695312, 19000000000.1, inf]
# HGB_div_EO
# 3.0    6122
# 1.0     966
# 2.0     880
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_BASO
# [-inf, 1.0, 10449999872.0, 10549999616.0, 17900000000.1, inf]
# HGB_div_BASO
# 1.0    6817
# 3.0    1149
# 0.0       3
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# HGB_div_NEUT%
# [-inf, 0.6911928651059086, 2.4466315507888794, 2.5571612119674683, 53.01666666666667, inf]
# HGB_div_NEUT%
# 1.0    6461
# 3.0    1183
# 2.0     311
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# HGB_div_LYBL%
# [-inf, 0.944055944055944, 5.619953632354736, 5.915780067443848, 82.4076923076923, inf]
# HGB_div_LYBL%
# 3.0    5407
# 1.0    2282
# 2.0     256
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# HGB_div_MONO%
# [-inf, 1.0, 16.219219207763672, 17.5806827545166, 11300000000.1, inf]
# HGB_div_MONO%
# 1.0    4510
# 3.0    2816
# 2.0     641
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# HGB_div_EO%
# [-inf, 1.0, 99.25823974609375, 171.33928680419922, 19000000000.1, inf]
# HGB_div_EO%
# 3.0    5169
# 1.0    1742
# 2.0    1057
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_BASO%
# [-inf, 1.0, 970.0, 1065.0, 17900000000.1, inf]
# HGB_div_BASO%
# 1.0    4976
# 3.0    2972
# 2.0      20
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_IG#
# [-inf, 1.0, 6725.0, 10649999872.0, 19000000000.1, inf]
# HGB_div_IG#
# 2.0    4281
# 1.0    2209
# 3.0    1478
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_IG%
# [-inf, 1.0, 1005.0, 1475.0, 19000000000.1, inf]
# HGB_div_IG%
# 1.0    4471
# 3.0    1842
# 2.0    1655
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_CRP
# [-inf, 0.3367249835297562, 77.37262725830078, 78.91729354858398, 17100000000.1, inf]
# HGB_div_CRP
# 1.0    7054
# 3.0     770
# 0.0     128
# 2.0      19
# Name: count, dtype: int64
# -----------------------
# HGB_div_HFLC1
# [-inf, 1.0, 4850.0, 4916.666748046875, 18500000000.1, inf]
# HGB_div_HFLC1
# 3.0    6394
# 1.0    1550
# 2.0      24
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_HFLC2
# [-inf, 1.0, 295.5, 491.6666717529297, 18500000000.1, inf]
# HGB_div_HFLC2
# 3.0    5599
# 1.0    1272
# 2.0    1097
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_NRBC#
# [-inf, 2.9649122807017536e-05, 8049999872.0, 10649999872.0, 20300000000.1, inf]
# HGB_div_NRBC#
# 3.0    5035
# 1.0    2808
# 2.0     125
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HGB_div_NRBC%
# [-inf, 2.8121309715512613e-06, 8049999872.0, 10649999872.0, 20300000000.1, inf]
# HGB_div_NRBC%
# 3.0    5035
# 1.0    2808
# 2.0     125
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_MCV
# [-inf, 0.1765295887662989, 0.393192321062088, 0.39396126568317413, 1.1, inf]
# HCT_div_MCV
# 3.0    7513
# 1.0     441
# 2.0       9
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# HCT_div_MCH
# [-inf, 0.5161290322580645, 1.1558037400245667, 1.2225860357284546, 2.450785340314136, inf]
# HCT_div_MCH
# 3.0    7083
# 2.0     487
# 1.0     393
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# HCT_div_MCHC
# [-inf, 0.0507598784194528, 0.12286987900733948, 0.1330370306968689, 1.1, inf]
# HCT_div_MCHC
# 1.0    3870
# 2.0    2196
# 3.0    1901
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# HCT_div_PLT
# [-inf, 0.039647577092511, 0.15992355346679688, 0.18166302889585495, 2.45, inf]
# HCT_div_PLT
# 3.0    4130
# 1.0    2491
# 2.0    1333
# 0.0      17
# Name: count, dtype: int64
# -----------------------
# HCT_div_RDW-SD
# [-inf, 0.2865111561866126, 1.0522053837776184, 1.0537640452384949, 1.603012048192771, inf]
# HCT_div_RDW-SD
# 1.0    5299
# 3.0    2628
# 2.0      43
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# HCT_div_RDW-CV
# [-inf, 0.8687782805429863, 3.2885122299194336, 3.3861643075942993, 5.059677419354839, inf]
# HCT_div_RDW-CV
# 1.0    4280
# 3.0    3095
# 2.0     595
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# HCT_div_PDW
# [-inf, 1.0, 2.763068199157715, 3.0689661502838135, 4620000000.1, inf]
# HCT_div_PDW
# 1.0    4213
# 3.0    2672
# 2.0    1063
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HCT_div_MPV
# [-inf, 1.0, 3.6034547090530396, 3.6731832027435303, 4620000000.1, inf]
# HCT_div_MPV
# 3.0    7120
# 1.0     666
# 2.0     162
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HCT_div_P-LCR
# [-inf, 0.3572542901716068, 2.8116413354873657, 2.8895903825759888, 4620000000.1, inf]
# HCT_div_P-LCR
# 1.0    6875
# 3.0     911
# 2.0     164
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# HCT_div_PCT
# [-inf, 1.0, 176.24159240722656, 179.0399398803711, 4620000000.1, inf]
# HCT_div_PCT
# 3.0    5008
# 1.0    2757
# 2.0     183
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# HCT_div_NEUT
# [-inf, 1.0, 5.718313455581665, 19.886738777160645, 505.1, inf]
# HCT_div_NEUT
# 2.0    5929
# 1.0    1624
# 3.0     399
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# HCT_div_LY
# [-inf, 1.0, 20.4382266998291, 25.569241523742676, 329.19090909090914, inf]
# HCT_div_LY
# 3.0    5520
# 1.0    1490
# 2.0     935
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# HCT_div_MONO
# [-inf, 0.971407624633431, 71.21748352050781, 78.83037185668945, 3450000000.1, inf]
# HCT_div_MONO
# 1.0    4871
# 3.0    2337
# 2.0     761
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# HCT_div_EO
# [-inf, 1.0, 337.38636779785156, 439.44444274902344, 5690000000.1, inf]
# HCT_div_EO
# 3.0    6110
# 1.0    1422
# 2.0     436
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_BASO
# [-inf, 1.0, 3270000000.0, 5650000000.1, inf]
# HCT_div_BASO
# 1.0    6827
# 2.0    1141
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_NEUT%
# [-inf, 0.2006688963210702, 0.7704685926437378, 0.8376016914844513, 16.475, inf]
# HCT_div_NEUT%
# 1.0    6803
# 3.0     733
# 2.0     420
# 0.0      15
# Name: count, dtype: int64
# -----------------------
# HCT_div_LYBL%
# [-inf, 0.324009324009324, 1.6795523166656494, 1.8046536445617676, 25.330769230769224, inf]
# HCT_div_LYBL%
# 3.0    5331
# 1.0    2265
# 2.0     350
# 0.0      25
# Name: count, dtype: int64
# -----------------------
# HCT_div_MONO%
# [-inf, 0.4934823091247672, 4.933699607849121, 5.320493936538696, 3450000000.1, inf]
# HCT_div_MONO%
# 1.0    4683
# 3.0    2716
# 2.0     570
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# HCT_div_EO%
# [-inf, 1.0, 30.519230842590332, 51.9375, 5690000000.1, inf]
# HCT_div_EO%
# 3.0    5141
# 1.0    1786
# 2.0    1041
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_BASO%
# [-inf, 1.0, 283.5, 328.0, 5650000000.1, inf]
# HCT_div_BASO%
# 1.0    4969
# 3.0    2968
# 2.0      31
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_IG#
# [-inf, 1.0, 2002.5, 3315000064.0, 5690000000.1, inf]
# HCT_div_IG#
# 2.0    4287
# 1.0    2201
# 3.0    1480
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_IG%
# [-inf, 0.8558139534883721, 315.5, 429.5, 5690000000.1, inf]
# HCT_div_IG%
# 1.0    4475
# 3.0    1994
# 2.0    1501
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# HCT_div_CRP
# [-inf, 0.1032135275602078, 10.99562692642212, 23.52306079864502, 5250000000.1, inf]
# HCT_div_CRP
# 1.0    6209
# 2.0     848
# 3.0     786
# 0.0     128
# Name: count, dtype: int64
# -----------------------
# HCT_div_HFLC1
# [-inf, 1.0, 1454.1666870117188, 1504.1666870117188, 5510000000.1, inf]
# HCT_div_HFLC1
# 3.0    6365
# 1.0    1558
# 2.0      45
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_HFLC2
# [-inf, 1.0, 86.2249984741211, 88.67499923706055, 5510000000.1, inf]
# HCT_div_HFLC2
# 3.0    6696
# 1.0    1241
# 2.0      31
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_NRBC#
# [-inf, 2.9649122807017536e-05, 3155000064.0, 3224999936.0, 6150000000.1, inf]
# HCT_div_NRBC#
# 3.0    5041
# 1.0    2895
# 2.0      32
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# HCT_div_NRBC%
# [-inf, 2.8121309715512613e-06, 3155000064.0, 3224999936.0, 6150000000.1, inf]
# HCT_div_NRBC%
# 3.0    5041
# 1.0    2895
# 2.0      32
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_MCH
# [-inf, 1.0, 3.0068143606185913, 3.10128653049469, 4.063190184049079, inf]
# MCV_div_MCH
# 1.0    4956
# 2.0    2263
# 3.0     731
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# MCV_div_MCHC
# [-inf, 0.1795986622073578, 0.25490204989910126, 0.2687036544084549, 1.1, inf]
# MCV_div_MCHC
# 3.0    3205
# 2.0    3132
# 1.0    1629
# 0.0       5
# Name: count, dtype: int64
# -----------------------
# MCV_div_PLT
# [-inf, 0.1125344352617079, 0.3218315541744232, 0.3561777025461197, 7.508333333333334, inf]
# MCV_div_PLT
# 3.0    5129
# 1.0    1876
# 2.0     948
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# MCV_div_RDW-SD
# [-inf, 0.6551724137931034, 2.193341612815857, 2.2145378589630127, 2.625641025641025, inf]
# MCV_div_RDW-SD
# 1.0    5325
# 3.0    2178
# 2.0     450
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# MCV_div_RDW-CV
# [-inf, 1.0, 6.892845869064331, 7.297292470932007, 9.31818181818182, inf]
# MCV_div_RDW-CV
# 1.0    3334
# 3.0    2479
# 2.0    2146
# 0.0      12
# Name: count, dtype: int64
# -----------------------
# MCV_div_PDW
# [-inf, 1.0, 5.6246018409729, 5.980580568313599, 8830000000.1, inf]
# MCV_div_PDW
# 1.0    3397
# 3.0    2897
# 2.0    1654
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCV_div_MPV
# [-inf, 1.0, 10.473763942718506, 10.494679927825928, 8830000000.1, inf]
# MCV_div_MPV
# 1.0    6583
# 3.0    1321
# 2.0      44
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCV_div_P-LCR
# [-inf, 1.0, 5.975445747375488, 6.747204303741455, 8830000000.1, inf]
# MCV_div_P-LCR
# 1.0    6825
# 3.0     622
# 2.0     501
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCV_div_PCT
# [-inf, 1.0, 332.8146667480469, 365.5868835449219, 8830000000.1, inf]
# MCV_div_PCT
# 3.0    5649
# 1.0    1446
# 2.0     853
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCV_div_NEUT
# [-inf, 1.0, 9.332530975341797, 10.780451774597168, 1068.85, inf]
# MCV_div_NEUT
# 3.0    6860
# 1.0     682
# 2.0     411
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# MCV_div_LY
# [-inf, 1.0, 44.90037727355957, 58.07098579406738, 805.5545454545454, inf]
# MCV_div_LY
# 3.0    5225
# 1.0    1591
# 2.0    1129
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# MCV_div_MONO
# [-inf, 1.0, 145.24199676513672, 159.11497497558594, 7690000000.1, inf]
# MCV_div_MONO
# 1.0    4425
# 3.0    2895
# 2.0     647
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCV_div_EO
# [-inf, 1.0, 525.753662109375, 834.3560791015625, 11390000000.1, inf]
# MCV_div_EO
# 3.0    6314
# 1.0     957
# 2.0     697
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_BASO
# [-inf, 1.0, 7485000192.0, 7745000192.0, 12920000000.099998, inf]
# MCV_div_BASO
# 1.0    6801
# 3.0    1152
# 2.0      15
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_NEUT%
# [-inf, 0.6898876404494382, 1.346569299697876, 1.6144591569900513, 37.85, inf]
# MCV_div_NEUT%
# 1.0    5099
# 2.0    1751
# 3.0    1107
# 0.0      14
# Name: count, dtype: int64
# -----------------------
# MCV_div_LYBL%
# [-inf, 0.717948717948718, 3.289936065673828, 3.290510058403015, 65.1, inf]
# MCV_div_LYBL%
# 3.0    6114
# 1.0    1824
# 0.0      31
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# MCV_div_MONO%
# [-inf, 1.0, 10.262866020202637, 10.327677726745605, 7690000000.1, inf]
# MCV_div_MONO%
# 1.0    4409
# 3.0    3505
# 2.0      53
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCV_div_EO%
# [-inf, 1.0, 67.11538314819336, 101.05555725097656, 10690000000.1, inf]
# MCV_div_EO%
# 3.0    5323
# 1.0    1812
# 2.0     833
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_BASO%
# [-inf, 1.0, 536.25, 739.5, 12920000000.099998, inf]
# MCV_div_BASO%
# 1.0    4954
# 3.0    2986
# 2.0      28
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_IG#
# [-inf, 1.0, 4217.5, 6175000064.0, 12920000000.099998, inf]
# MCV_div_IG#
# 2.0    4513
# 1.0    1930
# 3.0    1525
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_IG%
# [-inf, 1.0, 599.5, 9024999936.0, 12920000000.099998, inf]
# MCV_div_IG%
# 1.0    4446
# 2.0    3073
# 3.0     449
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_CRP
# [-inf, 0.3056965987340891, 23.491202354431152, 43.37686729431152, 9970000000.1, inf]
# MCV_div_CRP
# 1.0    6198
# 3.0     917
# 2.0     727
# 0.0     129
# Name: count, dtype: int64
# -----------------------
# MCV_div_HFLC1
# [-inf, 1.0, 3005.0, 3038.3333740234375, 11390000000.1, inf]
# MCV_div_HFLC1
# 3.0    6442
# 1.0    1484
# 2.0      42
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_HFLC2
# [-inf, 1.0, 216.375, 11390000000.1, inf]
# MCV_div_HFLC2
# 2.0    6535
# 1.0    1433
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_NRBC#
# [-inf, 2.9649122807017536e-05, 306571.9375, 5440000000.0, 12920000000.099998, inf]
# MCV_div_NRBC#
# 3.0    5196
# 1.0    2767
# 2.0       5
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCV_div_NRBC%
# [-inf, 2.8121309715512613e-06, 29077.4345703125, 5440000000.0, 12920000000.099998, inf]
# MCV_div_NRBC%
# 3.0    5196
# 1.0    2767
# 2.0       5
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_MCHC
# [-inf, 0.0533088235294117, 0.0872754156589508, 0.0894811600446701, 1.1, inf]
# MCH_div_MCHC
# 3.0    3767
# 1.0    2594
# 2.0    1606
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCH_div_PLT
# [-inf, 0.0355871886120996, 0.10960426926612854, 0.12120606377720833, 2.541666666666667, inf]
# MCH_div_PLT
# 3.0    4922
# 1.0    2057
# 2.0     971
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# MCH_div_RDW-SD
# [-inf, 0.165314401622718, 0.7199045717716217, 0.7665875852108002, 1.1, inf]
# MCH_div_RDW-SD
# 1.0    4099
# 2.0    2647
# 3.0    1215
# 0.0      10
# Name: count, dtype: int64
# -----------------------
# MCH_div_RDW-CV
# [-inf, 0.6832579185520361, 2.3018728494644165, 2.306828022003174, 3.2775700934579444, inf]
# MCH_div_RDW-CV
# 3.0    4657
# 1.0    3239
# 2.0      67
# 0.0       8
# Name: count, dtype: int64
# -----------------------
# MCH_div_PDW
# [-inf, 0.9415584415584416, 1.8251506090164185, 2.0247679948806763, 2890000000.1, inf]
# MCH_div_PDW
# 2.0    3008
# 3.0    2938
# 1.0    2004
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# MCH_div_MPV
# [-inf, 1.0, 2.590692639350891, 3.468219757080078, 2890000000.1, inf]
# MCH_div_MPV
# 2.0    5748
# 3.0    1703
# 1.0     497
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCH_div_P-LCR
# [-inf, 0.4477379095163807, 1.9676372408866882, 2.2490875720977783, 2890000000.1, inf]
# MCH_div_P-LCR
# 1.0    6682
# 3.0     647
# 2.0     621
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# MCH_div_PCT
# [-inf, 1.0, 113.31989288330078, 119.54284286499023, 2890000000.1, inf]
# MCH_div_PCT
# 3.0    5814
# 1.0    1636
# 2.0     498
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCH_div_NEUT
# [-inf, 1.0, 3.771186947822571, 3.7774864435195923, 366.35, inf]
# MCH_div_NEUT
# 3.0    6699
# 1.0    1252
# 0.0      18
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# MCH_div_LY
# [-inf, 1.0, 15.171273231506348, 20.138410568237305, 278.2818181818182, inf]
# MCH_div_LY
# 3.0    5024
# 1.0    1639
# 2.0    1282
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# MCH_div_MONO
# [-inf, 1.0, 47.79536437988281, 52.956892013549805, 2530000000.1, inf]
# MCH_div_MONO
# 1.0    4290
# 3.0    2923
# 2.0     754
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCH_div_EO
# [-inf, 1.0, 172.8594741821289, 270.4166717529297, 3940000000.1, inf]
# MCH_div_EO
# 3.0    6364
# 1.0     943
# 2.0     661
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_BASO
# [-inf, 1.0, 2244999936.0, 2534999936.0, 3650000000.1, inf]
# MCH_div_BASO
# 1.0    6796
# 3.0    1146
# 2.0      26
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_NEUT%
# [-inf, 0.2071428571428571, 0.520034909248352, 0.5444735288619995, 12.308333333333334, inf]
# MCH_div_NEUT%
# 1.0    6617
# 3.0    1059
# 2.0     278
# 0.0      17
# Name: count, dtype: int64
# -----------------------
# MCH_div_LYBL%
# [-inf, 0.2086247086247086, 0.9302354753017426, 1.2729098200798035, 21.407692307692308, inf]
# MCH_div_LYBL%
# 3.0    5368
# 2.0    1392
# 1.0    1179
# 0.0      32
# Name: count, dtype: int64
# -----------------------
# MCH_div_MONO%
# [-inf, 0.6089385474860335, 3.35196053981781, 3.485857844352722, 2530000000.1, inf]
# MCH_div_MONO%
# 1.0    4200
# 3.0    3442
# 2.0     327
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# MCH_div_EO%
# [-inf, 1.0, 15.885621070861816, 34.16666603088379, 3650000000.1, inf]
# MCH_div_EO%
# 3.0    5307
# 2.0    1423
# 1.0    1238
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_BASO%
# [-inf, 1.0, 205.5, 232.0, 3650000000.1, inf]
# MCH_div_BASO%
# 1.0    4965
# 3.0    2988
# 2.0      15
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_IG#
# [-inf, 1.0, 1477.5, 1745000000.0, 3940000000.1, inf]
# MCH_div_IG#
# 2.0    4241
# 1.0    2202
# 3.0    1525
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_IG%
# [-inf, 1.0, 185.0, 2985000064.0, 3500000000.1, inf]
# MCH_div_IG%
# 1.0    4445
# 2.0    2981
# 3.0     542
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_CRP
# [-inf, 0.1046775492277285, 7.8375084400177, 14.509249687194824, 3340000000.1, inf]
# MCH_div_CRP
# 1.0    6207
# 3.0     912
# 2.0     723
# 0.0     129
# Name: count, dtype: int64
# -----------------------
# MCH_div_HFLC1
# [-inf, 1.0, 985.0, 1477.5, 3940000000.1, inf]
# MCH_div_HFLC1
# 3.0    5796
# 1.0    1421
# 2.0     751
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_HFLC2
# [-inf, 1.0, 74.125, 97.16666793823242, 3940000000.1, inf]
# MCH_div_HFLC2
# 3.0    5923
# 1.0    1522
# 2.0     523
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCH_div_NRBC#
# [-inf, 2.9649122807017536e-05, 1480000000.0, 1635000000.0, 3940000000.1, inf]
# MCH_div_NRBC#
# 3.0    5195
# 1.0    2771
# 0.0       3
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# MCH_div_NRBC%
# [-inf, 2.8121309715512613e-06, 1480000000.0, 1635000000.0, 3940000000.1, inf]
# MCH_div_NRBC%
# 3.0    5195
# 1.0    2771
# 0.0       3
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# MCHC_div_PLT
# [-inf, 0.4476584022038568, 1.1530430912971497, 1.199644148349762, 27.51666666666667, inf]
# MCHC_div_PLT
# 3.0    6243
# 1.0    1394
# 2.0     315
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# MCHC_div_RDW-SD
# [-inf, 1.0, 6.936311483383179, 7.212064743041992, 10.973493975903613, inf]
# MCHC_div_RDW-SD
# 3.0    7229
# 1.0     408
# 2.0     328
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# MCHC_div_RDW-CV
# [-inf, 1.0, 26.53059196472168, 27.28406810760498, 33.09065420560748, inf]
# MCHC_div_RDW-CV
# 1.0    4411
# 3.0    2281
# 2.0    1266
# 0.0      13
# Name: count, dtype: int64
# -----------------------
# MCHC_div_PDW
# [-inf, 1.0, 22.621292114257812, 22.83808422088623, 34700000000.1, inf]
# MCHC_div_PDW
# 1.0    5275
# 3.0    2657
# 0.0      23
# 2.0      16
# Name: count, dtype: int64
# -----------------------
# MCHC_div_MPV
# [-inf, 1.0, 39.24038505554199, 39.259145736694336, 34700000000.1, inf]
# MCHC_div_MPV
# 1.0    6463
# 3.0    1484
# 0.0      23
# 2.0       1
# Name: count, dtype: int64
# -----------------------
# MCHC_div_P-LCR
# [-inf, 1.0, 21.587318420410156, 24.132885932922363, 34700000000.1, inf]
# MCHC_div_P-LCR
# 1.0    6540
# 3.0     813
# 2.0     595
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCHC_div_PCT
# [-inf, 1.0, 1408.6031494140625, 1430.4072875976562, 34700000000.1, inf]
# MCHC_div_PCT
# 3.0    5237
# 1.0    2521
# 2.0     190
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# MCHC_div_NEUT
# [-inf, 1.0, 34.981422424316406, 140.94871520996094, 4300.1, inf]
# MCHC_div_NEUT
# 2.0    6691
# 1.0     636
# 3.0     626
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# MCHC_div_LY
# [-inf, 1.0, 173.7879180908203, 212.11156463623047, 3136.4636363636364, inf]
# MCHC_div_LY
# 3.0    5371
# 1.0    1677
# 2.0     896
# 0.0      27
# Name: count, dtype: int64
# -----------------------
# MCHC_div_MONO
# [-inf, 1.0, 562.5034790039062, 586.7388610839844, 32800000000.1, inf]
# MCHC_div_MONO
# 1.0    4639
# 3.0    3014
# 2.0     314
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCHC_div_EO
# [-inf, 1.0, 2060.6617431640625, 3242.727294921875, 36400000000.1, inf]
# MCHC_div_EO
# 3.0    6272
# 1.0     990
# 2.0     706
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCHC_div_BASO
# [-inf, 1.0, 34450.0, 12550020116.0, 35800000000.1, inf]
# MCHC_div_BASO
# 1.0    6411
# 3.0    1187
# 2.0     370
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCHC_div_NEUT%
# [-inf, 1.0, 5.62445068359375, 5.721694469451904, 134.68333333333334, inf]
# MCHC_div_NEUT%
# 1.0    6337
# 3.0    1497
# 2.0     121
# 0.0      16
# Name: count, dtype: int64
# -----------------------
# MCHC_div_LYBL%
# [-inf, 1.0, 12.490774631500244, 13.191484451293945, 250.8692307692308, inf]
# MCHC_div_LYBL%
# 3.0    5809
# 1.0    1856
# 2.0     273
# 0.0      33
# Name: count, dtype: int64
# -----------------------
# MCHC_div_MONO%
# [-inf, 1.0, 36.79505920410156, 38.663190841674805, 32800000000.1, inf]
# MCHC_div_MONO%
# 1.0    3998
# 3.0    3566
# 2.0     403
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MCHC_div_EO%
# [-inf, 1.0, 195.45955657958984, 398.125, 36400000000.1, inf]
# MCHC_div_EO%
# 3.0    5261
# 1.0    1366
# 2.0    1341
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCHC_div_BASO%
# [-inf, 1.0, 1742.5, 2380.0, 35800000000.1, inf]
# MCHC_div_BASO%
# 1.0    4879
# 3.0    3014
# 2.0      75
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MCHC_div_IG#
# [-inf, 1.0, 11283.33349609375, 35750.0, 41000000000.1, inf]
# MCHC_div_IG#
# 2.0    5001
# 3.0    1532
# 1.0    1435
# 0.0       3
# Name: count, dtype: int64
# ...
# -----------------------
# BASO_div_NEUT%
# [-inf, 1.0427528675703856e-10, 5.257704351874226e-05, 0.00011166949479957111, 1.1, inf]
# BASO_div_NEUT%
# 3.0    6737
# 1.0    1186
# 2.0      44
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# BASO_div_LYBL%
# [-inf, 1.2048192771084339e-10, 0.0003976158914156258, 0.0004402056656545028, 1.1, inf]
# BASO_div_LYBL%
# 3.0    5688
# 1.0    2055
# 2.0     224
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# BASO_div_MONO%
# [-inf, 1.8621973929236496e-10, 0.00013022500679049642, 1.1, inf]
# BASO_div_MONO%
# 2.0    6781
# 1.0    1185
# 0.0       5
# Name: count, dtype: int64
# -----------------------
# BASO_div_EO%
# [-inf, 9.803921568627451e-10, 0.007059800671413541, 0.018350168131291866, 8000000.1, inf]
# BASO_div_EO%
# 3.0    4856
# 1.0    1671
# 2.0    1403
# 0.0      41
# Name: count, dtype: int64
# -----------------------
# BASO_div_BASO%
# [-inf, 5e-08, 0.08819444477558136, 0.23333334177732468, 1000000.1, inf]
# BASO_div_BASO%
# 1.0    3814
# 2.0    3151
# 3.0    1000
# 0.0       6
# Name: count, dtype: int64
# -----------------------
# BASO_div_IG#
# [-inf, 1.8975332068311197e-09, 0.03113026823848486, 0.7750000059604645, 7000000.100000001, inf]
# BASO_div_IG#
# 3.0    5357
# 2.0    1674
# 1.0     887
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# BASO_div_IG%
# [-inf, 4.926108374384235e-10, 0.0007588739099446684, 7000000.100000001, inf]
# BASO_div_IG%
# 2.0    6940
# 1.0     981
# 0.0      50
# Name: count, dtype: int64
# -----------------------
# BASO_div_CRP
# [-inf, 3.4777770049384434e-11, 2.175090575384786e-05, 0.0001918195266625844, 8000000.1, inf]
# BASO_div_CRP
# 3.0    6477
# 1.0    1183
# 2.0     224
# 0.0      87
# Name: count, dtype: int64
# -----------------------
# BASO_div_HFLC1
# [-inf, 1.5151515151515152e-08, 0.3484848588705063, 0.40833333134651184, 10000000.1, inf]
# BASO_div_HFLC1
# 3.0    6108
# 1.0    1783
# 2.0      43
# 0.0      37
# Name: count, dtype: int64
# -----------------------
# BASO_div_HFLC2
# [-inf, 1.2048192771084335e-09, 0.02440476231276989, 10000000.1, inf]
# BASO_div_HFLC2
# 2.0    6223
# 1.0    1708
# 0.0      40
# Name: count, dtype: int64
# -----------------------
# BASO_div_NRBC#
# [-inf, 4.2735042735042736e-08, 1.5037594437599182, 192.71929168701172, 11000000.1, inf]
# BASO_div_NRBC#
# 3.0    4102
# 2.0    2633
# 1.0    1217
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# BASO_div_NRBC%
# [-inf, 1.923076923076923e-08, 1.9060654640197754, 18.27885150909424, 11000000.1, inf]
# BASO_div_NRBC%
# 3.0    4102
# 2.0    2628
# 1.0    1222
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_LYBL%
# [-inf, 0.0286054827175208, 2.4928812980651855, 2.6088799238204956, 63.5, inf]
# NEUT%_div_LYBL%
# 3.0    5625
# 1.0    2137
# 2.0     178
# 0.0      31
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_MONO%
# [-inf, 0.1791044776119403, 6.646538257598877, 8.170196056365967, 8980000000.1, inf]
# NEUT%_div_MONO%
# 3.0    3523
# 1.0    3151
# 2.0    1295
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_EO%
# [-inf, 1.0, 36.545955657958984, 48.606061935424805, 9510000000.1, inf]
# NEUT%_div_EO%
# 3.0    6134
# 1.0    1399
# 2.0     435
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_BASO%
# [-inf, 1.0, 426.25, 310000475.5, 9590000000.1, inf]
# NEUT%_div_BASO%
# 1.0    4900
# 2.0    2074
# 3.0     994
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_IG#
# [-inf, 1.0, 3098.3333740234375, 9435.0, 9220000000.1, inf]
# NEUT%_div_IG#
# 2.0    4476
# 1.0    1964
# 3.0    1528
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_IG%
# [-inf, 1.0, 453.5, 6014999808.0, 9220000000.1, inf]
# NEUT%_div_IG%
# 1.0    4549
# 2.0    2703
# 3.0     716
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_CRP
# [-inf, 0.06006006006006, 25.208678245544434, 26.964165687561035, 8980000000.1, inf]
# NEUT%_div_CRP
# 1.0    6685
# 3.0    1091
# 0.0     119
# 2.0      76
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_HFLC1
# [-inf, 1.0, 2095.8333740234375, 2818.3333740234375, 9510000000.1, inf]
# NEUT%_div_HFLC1
# 3.0    6096
# 1.0    1367
# 2.0     505
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_HFLC2
# [-inf, 0.9166666666666669, 143.875, 159.36666107177734, 9510000000.1, inf]
# NEUT%_div_HFLC2
# 3.0    6435
# 1.0    1386
# 2.0     149
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_NRBC#
# [-inf, 2.9649122807017536e-05, 254537.71875, 267879.828125, 9590000000.1, inf]
# NEUT%_div_NRBC#
# 3.0    5214
# 1.0    2643
# 2.0     111
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# NEUT%_div_NRBC%
# [-inf, 2.8121309715512613e-06, 24142.14453125, 25407.603515625, 9590000000.1, inf]
# NEUT%_div_NRBC%
# 3.0    5214
# 1.0    2643
# 2.0     111
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_MONO%
# [-inf, 0.0646766169154228, 2.5786893367767334, 3.1364240646362305, 1000000000.1, inf]
# LYBL%_div_MONO%
# 1.0    5640
# 3.0    1637
# 2.0     692
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_EO%
# [-inf, 0.6934306569343066, 799.5, 865000000.0, 6560000000.099999, inf]
# LYBL%_div_EO%
# 1.0    6900
# 3.0     771
# 2.0     254
# 0.0      46
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_BASO%
# [-inf, 1.0, 131.58333587646484, 202.25, 8300000000.1, inf]
# LYBL%_div_BASO%
# 1.0    5289
# 3.0    1693
# 2.0     914
# 0.0      75
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_IG#
# [-inf, 0.8159392789373814, 2132.5, 2844999936.0, 8300000000.1, inf]
# LYBL%_div_IG#
# 1.0    5061
# 2.0    2335
# 3.0     557
# 0.0      18
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_IG%
# [-inf, 0.2118226600985221, 173.25, 192.75, 8300000000.1, inf]
# LYBL%_div_IG%
# 1.0    5289
# 3.0    2442
# 2.0     213
# 0.0      27
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_CRP
# [-inf, 0.0089537846959156, 5.477298021316528, 7.26822304725647, 6820000000.1, inf]
# LYBL%_div_CRP
# 1.0    6228
# 3.0    1352
# 2.0     320
# 0.0      71
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_HFLC1
# [-inf, 1.0, 717.0833435058594, 435000000.0, 4810000000.1, inf]
# LYBL%_div_HFLC1
# 2.0    4225
# 3.0    1900
# 1.0    1833
# 0.0      13
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_HFLC2
# [-inf, 1.0, 61.845237731933594, 515000000.0, 4810000000.1, inf]
# LYBL%_div_HFLC2
# 2.0    4231
# 1.0    2187
# 3.0    1526
# 0.0      27
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_NRBC#
# [-inf, 2.9649122807017536e-05, 115335.0859375, 1825000000.0, 8580000000.1, inf]
# LYBL%_div_NRBC#
# 1.0    2666
# 2.0    2654
# 3.0    2647
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# LYBL%_div_NRBC%
# [-inf, 2.8121309715512613e-06, 10939.189453125, 1825000000.0, 8580000000.1, inf]
# LYBL%_div_NRBC%
# 1.0    2666
# 2.0    2654
# 3.0    2647
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MONO%_div_EO%
# [-inf, 1e-07, 4.874176502227783, 8.343137264251709, 5370000000.1, inf]
# MONO%_div_EO%
# 3.0    5681
# 1.0    1376
# 2.0     894
# 0.0      20
# Name: count, dtype: int64
# -----------------------
# MONO%_div_BASO%
# [-inf, 1e-07, 198.5, 305000000.0, 5370000000.1, inf]
# MONO%_div_BASO%
# 1.0    6971
# 3.0     942
# 2.0      37
# 0.0      21
# Name: count, dtype: int64
# -----------------------
# MONO%_div_IG#
# [-inf, 9.090909090909093e-08, 285.8333282470703, 305000000.0, 2670000000.1, inf]
# MONO%_div_IG#
# 2.0    4828
# 1.0    1619
# 3.0    1522
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# MONO%_div_IG%
# [-inf, 2.3255813953488364e-09, 305000000.0, 1165000000.0, 2670000000.1, inf]
# MONO%_div_IG%
# 1.0    6769
# 2.0     724
# 3.0     469
# 0.0       9
# Name: count, dtype: int64
# -----------------------
# MONO%_div_CRP
# [-inf, 1.2006243246488174e-10, 3.547101855278015, 7.618248701095581, 2410000000.1, inf]
# MONO%_div_CRP
# 1.0    6635
# 2.0     669
# 3.0     567
# 0.0     100
# Name: count, dtype: int64
# -----------------------
# MONO%_div_HFLC1
# [-inf, 3.3333333333333335e-07, 354.1666717529297, 747.5, 3840000000.1, inf]
# MONO%_div_HFLC1
# 3.0    4274
# 2.0    1868
# 1.0    1827
# 0.0       2
# Name: count, dtype: int64
# -----------------------
# MONO%_div_HFLC2
# [-inf, 8.333333333333334e-09, 22.633333206176758, 23.708333015441895, 3840000000.1, inf]
# MONO%_div_HFLC2
# 3.0    6288
# 1.0    1592
# 2.0      88
# 0.0       3
# Name: count, dtype: int64
# -----------------------
# MONO%_div_NRBC#
# [-inf, 2.9649122807017536e-05, 15056926.31640625, 155000000.0, 3090000000.1, inf]
# MONO%_div_NRBC#
# 3.0    5187
# 1.0    2771
# 2.0       9
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# MONO%_div_NRBC%
# [-inf, 2.8121309715512613e-06, 15005399.291503906, 155000000.0, 3090000000.1, inf]
# MONO%_div_NRBC%
# 3.0    5187
# 1.0    2771
# 2.0       9
# 0.0       4
# Name: count, dtype: int64
# -----------------------
# EO%_div_BASO%
# [-inf, 7.142857142857144e-09, 4.366666793823242, 12.900000095367432, 1020000000.1, inf]
# EO%_div_BASO%
# 1.0    5145
# 2.0    1453
# 3.0    1291
# 0.0      82
# Name: count, dtype: int64
# -----------------------
# EO%_div_IG#
# [-inf, 1.0989010989010988e-08, 1.3563218712806702, 71.25, 1460000000.1, inf]
# EO%_div_IG#
# 2.0    3934
# 3.0    2831
# 1.0    1135
# 0.0      71
# Name: count, dtype: int64
# -----------------------
# EO%_div_IG%
# [-inf, 4.6511627906976733e-10, 1.024999976158142, 7.633333206176758, 1460000000.1, inf]
# EO%_div_IG%
# 1.0    2864
# 2.0    2704
# 3.0    2328
# 0.0      75
# Name: count, dtype: int64
# -----------------------
# EO%_div_CRP
# [-inf, 3.4777770049384434e-11, 0.1282799318432808, 0.3750571757555008, 780000000.1, inf]
# EO%_div_CRP
# 1.0    5533
# 3.0    1316
# 2.0    1077
# 0.0      45
# Name: count, dtype: int64
# -----------------------
# EO%_div_HFLC1
# [-inf, 1.5151515151515152e-08, 1.091269850730896, 805.0, 1430000000.1, inf]
# EO%_div_HFLC1
# 2.0    5223
# 3.0    1592
# 1.0    1103
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# EO%_div_HFLC2
# [-inf, 2.127659574468085e-09, 0.006024146161127675, 121.5, 1430000000.1, inf]
# EO%_div_HFLC2
# 2.0    5874
# 3.0    1286
# 1.0     759
# 0.0      52
# Name: count, dtype: int64
# -----------------------
# EO%_div_NRBC#
# [-inf, 4.2735042735042736e-08, 13193.85986328125, 35000000.0, 1460000000.1, inf]
# EO%_div_NRBC#
# 1.0    3226
# 3.0    3069
# 2.0    1628
# 0.0      48
# Name: count, dtype: int64
# -----------------------
# EO%_div_NRBC%
# [-inf, 4.901960784313725e-09, 1251.3983154296875, 35000000.0, 1460000000.1, inf]
# EO%_div_NRBC%
# 1.0    3226
# 3.0    3069
# 2.0    1628
# 0.0      48
# Name: count, dtype: int64
# -----------------------
# BASO%_div_IG#
# [-inf, 1.8975332068311197e-09, 1.0435571670532227, 7.083333253860474, 390000000.1, inf]
# BASO%_div_IG#
# 3.0    5470
# 2.0    1403
# 1.0    1068
# 0.0      30
# Name: count, dtype: int64
# -----------------------
# BASO%_div_IG%
# [-inf, 4.926108374384235e-10, 0.005263208120215523, 0.5505050718784332, 130000000.1, inf]
# BASO%_div_IG%
# 3.0    5512
# 2.0    1581
# 1.0     824
# 0.0      54
# Name: count, dtype: int64
# -----------------------
# BASO%_div_CRP
# [-inf, 3.4777770049384434e-11, 0.00018302770312494943, 0.002327476628124714, 100000000.1, inf]
# BASO%_div_CRP
# 3.0    6590
# 1.0     990
# 2.0     301
# 0.0      90
# Name: count, dtype: int64
# -----------------------
# BASO%_div_HFLC1
# [-inf, 1.5151515151515152e-08, 8.452380657196045, 9.285714149475098, 140000000.1, inf]
# BASO%_div_HFLC1
# 3.0    5615
# 1.0    2327
# 0.0      27
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# BASO%_div_HFLC2
# [-inf, 1.2048192771084335e-09, 0.395652174949646, 0.40833333134651184, 140000000.1, inf]
# BASO%_div_HFLC2
# 3.0    6016
# 1.0    1869
# 2.0      63
# 0.0      23
# Name: count, dtype: int64
# -----------------------
# BASO%_div_NRBC#
# [-inf, 4.2735042735042736e-08, 1.75, 2816.666748046875, 390000000.1, inf]
# BASO%_div_NRBC#
# 3.0    4287
# 2.0    2671
# 1.0     998
# 0.0      15
# Name: count, dtype: int64
# -----------------------
# BASO%_div_NRBC%
# [-inf, 1.923076923076923e-08, 1.3226743936538696, 267.1524429321289, 390000000.1, inf]
# BASO%_div_NRBC%
# 3.0    4287
# 2.0    2645
# 1.0    1024
# 0.0      15
# Name: count, dtype: int64
# -----------------------
# IG#_div_IG%
# [-inf, 9.09090909090909e-09, 0.09800000116229057, 1.1, inf]
# IG#_div_IG%
# 2.0    4938
# 1.0    3032
# 0.0       1
# Name: count, dtype: int64
# -----------------------
# IG#_div_CRP
# [-inf, 6.745817593092283e-11, 0.005046261008828878, 0.009872482158243656, 14000000.100000001, inf]
# IG#_div_CRP
# 1.0    6641
# 3.0     752
# 2.0     552
# 0.0      26
# Name: count, dtype: int64
# -----------------------
# IG#_div_HFLC1
# [-inf, 2.5641025641025643e-08, 0.949999988079071, 37000000.1, inf]
# IG#_div_HFLC1
# 2.0    5176
# 1.0    2742
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# IG#_div_HFLC2
# [-inf, 1.111111111111111e-09, 0.048076923936605453, 0.7463270425796509, 37000000.1, inf]
# IG#_div_HFLC2
# 2.0    3651
# 1.0    2562
# 3.0    1701
# 0.0      57
# Name: count, dtype: int64
# -----------------------
# IG#_div_NRBC#
# [-inf, 1.3513513513513517e-07, 222.36841583251953, 696.7543640136719, 527000000.1, inf]
# IG#_div_NRBC#
# 3.0    4314
# 1.0    3591
# 2.0      59
# 0.0       7
# Name: count, dtype: int64
# -----------------------
# IG#_div_NRBC%
# [-inf, 4.608294930875576e-09, 21.09098243713379, 66.08507919311523, 527000000.1, inf]
# IG#_div_NRBC%
# 3.0    4314
# 1.0    3589
# 2.0      61
# 0.0       7
# Name: count, dtype: int64
# -----------------------
# IG%_div_CRP
# [-inf, 8.847991505928155e-11, 0.050697166472673416, 0.10454808548092842, 180000000.1, inf]
# IG%_div_CRP
# 1.0    6331
# 3.0     888
# 2.0     733
# 0.0      19
# Name: count, dtype: int64
# -----------------------
# IG%_div_HFLC1
# [-inf, 2.5641025641025643e-08, 8.541666507720947, 9.44444465637207, 850000000.1, inf]
# IG%_div_HFLC1
# 3.0    5237
# 1.0    2688
# 0.0      44
# 2.0       2
# Name: count, dtype: int64
# -----------------------
# IG%_div_HFLC2
# [-inf, 2.127659574468085e-09, 0.4365079402923584, 0.949999988079071, 850000000.1, inf]
# IG%_div_HFLC2
# 3.0    4972
# 1.0    2107
# 2.0     846
# 0.0      46
# Name: count, dtype: int64
# -----------------------
# IG%_div_NRBC#
# [-inf, 1.3513513513513517e-07, 6226.31591796875, 18678.947265625, 2030000000.1, inf]
# IG%_div_NRBC#
# 3.0    4617
# 1.0    3326
# 0.0      20
# 2.0       8
# Name: count, dtype: int64
# -----------------------
# IG%_div_NRBC%
# [-inf, 4.608294930875576e-09, 590.5475158691406, 1771.6425170898438, 2030000000.1, inf]
# IG%_div_NRBC%
# 3.0    4617
# 1.0    3326
# 0.0      20
# 2.0       8
# Name: count, dtype: int64
# -----------------------
# CRP_div_HFLC1
# [-inf, 7.142857142857142e-08, 214.33333587646484, 353.5833282470703, 23613000000.1, inf]
# CRP_div_HFLC1
# 3.0    5729
# 1.0    1629
# 2.0     557
# 0.0      56
# Name: count, dtype: int64
# -----------------------
# CRP_div_HFLC2
# [-inf, 2.380952380952381e-09, 19.636666297912598, 19.96749973297119, 25835000000.1, inf]
# CRP_div_HFLC2
# 3.0    5923
# 1.0    1962
# 0.0      60
# 2.0      26
# Name: count, dtype: int64
# -----------------------
# CRP_div_NRBC#
# [-inf, 2.9649122807017536e-05, 199004.90625, 10326837.09375, 28754000000.1, inf]
# CRP_div_NRBC#
# 3.0    5151
# 1.0    2587
# 0.0     178
# 2.0      55
# Name: count, dtype: int64
# -----------------------
# CRP_div_NRBC%
# [-inf, 2.8121309715512613e-06, 18875.0224609375, 10030999.525390625, 28754000000.1, inf]
# CRP_div_NRBC%
# 3.0    5151
# 1.0    2587
# 0.0     178
# 2.0      55
# Name: count, dtype: int64
# -----------------------
# HFLC1_div_HFLC2
# [-inf, 5e-08, 0.6500000059604645, 1000000.1, inf]
# HFLC1_div_HFLC2
# 1.0    6316
# 2.0    1592
# 0.0      63
# Name: count, dtype: int64
# -----------------------
# HFLC1_div_NRBC#
# [-inf, 1e-07, 1500000.0, 2500000.0, 116000000.1, inf]
# HFLC1_div_NRBC#
# 1.0    5707
# 3.0    1296
# 2.0     915
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# HFLC1_div_NRBC%
# [-inf, 6.25e-09, 1500000.0, 2500000.0, 116000000.1, inf]
# HFLC1_div_NRBC%
# 1.0    5707
# 3.0    1296
# 2.0     915
# 0.0      53
# Name: count, dtype: int64
# -----------------------
# HFLC2_div_NRBC#
# [-inf, 2.5e-07, 2223.6842041015625, 25000000.0, 1560000000.1, inf]
# HFLC2_div_NRBC#
# 1.0    3185
# 2.0    2871
# 3.0    1858
# 0.0      57
# Name: count, dtype: int64
# -----------------------
# HFLC2_div_NRBC%
# [-inf, 1.5625e-08, 210.90982055664062, 25000000.0, 1560000000.1, inf]
# HFLC2_div_NRBC%
# 1.0    3185
# 2.0    2871
# 3.0    1858
# 0.0      57
# Name: count, dtype: int64
# -----------------------
# NRBC#_div_NRBC%
# [-inf, 0.0211538461538461, 0.13051948323845863, 0.7543478310108185, 1.1, inf]
# NRBC#_div_NRBC%
# 3.0    5198
# 1.0    2762
# 2.0      10
# 0.0       1
# Name: count, dtype: int64
# -----------------------

# %%
# check if there is any nan
X_bin.isna().sum()
# Out:
# PtAge              0
# WBC                0
# RBC                0
# HGB                0
# HCT                0
#                   ..
# HFLC1_div_NRBC#    0
# HFLC1_div_NRBC%    0
# HFLC2_div_NRBC#    0
# HFLC2_div_NRBC%    0
# NRBC#_div_NRBC%    0
# Length: 528, dtype: int64

# %%
X_bin.to_csv('../data/curated/combined_data_div_binned.csv', index=False)
# X_reduced.to_csv('../data/curated/combined_data_div_binned_reduced.csv', index=False)
y.to_csv('../data/curated/combined_label.csv', index=False)

# %%
# build a multioutput classifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

X_train, X_test, y_train, y_test = train_test_split(X_bin, y, test_size=0.2, random_state=42)

forest = RandomForestClassifier(n_estimators=100, random_state=42)
multi_target_forest = MultiOutputClassifier(forest, n_jobs=-1)
multi_target_forest.fit(X_train, y_train)
y_pred = multi_target_forest.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.55      0.68       459
#            1       0.58      0.45      0.50       522
#
#    micro avg       0.71      0.49      0.58       981
#    macro avg       0.73      0.50      0.59       981
# weighted avg       0.72      0.49      0.58       981
#  samples avg       0.30      0.30      0.30       981
# /Users/yulindong/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/yulindong/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
